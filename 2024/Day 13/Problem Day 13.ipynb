# %% [markdown]
# Part 1

# %%
import math

def parse_input(file_path):
    with open(file_path, "r") as file:
        data = file.read().strip().split("\n\n")

    machines = []
    for block in data:
        lines = block.split("\n")
        button_a = tuple(map(int, lines[0].split("X+")[1].split(", Y+")))
        button_b = tuple(map(int, lines[1].split("X+")[1].split(", Y+")))
        prize = tuple(map(int, lines[2].split("X=")[1].split(", Y=")))
        machines.append((button_a, button_b, prize))

    return machines

def solve_claw_machine(button_a, button_b, prize):
    a, c = button_a
    b, d = button_b
    X, Y = prize

    min_cost = float('inf')
    best_na, best_nb = None, None

    # Iterate over possible n_A values
    for n_A in range(101):
        rem_x = X - n_A * a
        rem_y = Y - n_A * c

        if rem_x % b == 0 and rem_y % d == 0:
            n_B_x = rem_x // b
            n_B_y = rem_y // d

            if n_B_x == n_B_y and n_B_x >= 0:
                cost = 3 * n_A + n_B_x
                if cost < min_cost:
                    min_cost = cost
                    best_na, best_nb = n_A, n_B_x

    return min_cost if best_na is not None else None

def main(file_path):
    machines = parse_input(file_path)
    total_cost = 0
    prizes_won = 0

    for button_a, button_b, prize in machines:
        result = solve_claw_machine(button_a, button_b, prize)
        if result is not None:
            total_cost += result
            prizes_won += 1

    print(f"Prizes Won: {prizes_won}")
    print(f"Minimum Tokens Spent: {total_cost}")

# Example usage
main("input.txt")
# Out:
# Prizes Won: 151
# Minimum Tokens Spent: 31589

# %% [markdown]
# Part 2

# %%
def extended_gcd(a, b):
    if a == 0:
        return b, 0, 1
    gcd, x1, y1 = extended_gcd(b % a, a)
    x = y1 - (b // a) * x1
    y = x1
    return gcd, x, y

def find_solution(a1, a2, b1, b2, target_x, target_y):
    print(f"\nSolving for equations:")
    print(f"{a1}A + {b1}B = {target_x}")
    print(f"{a2}A + {b2}B = {target_y}")

    # Calculate determinant
    det = a1 * b2 - a2 * b1

    if det == 0:
        print("No solution - equations are dependent")
        return None

    # Using Cramer's rule
    n = (target_x * b2 - target_y * b1) / det
    m = (a1 * target_y - a2 * target_x) / det

    # Check if solution is integer and non-negative
    if n != int(n) or m != int(m) or n < 0 or m < 0:
        print(f"No valid solution: A={n}, B={m}")
        return None

    n = int(n)
    m = int(m)

    # Verify solution
    if (a1 * n + b1 * m == target_x) and (a2 * n + b2 * m == target_y):
        print(f"Found solution: A={n}, B={m}")
        return (n, m)

    return None

def solve_claw_machines_part2(input_data):
    total_tokens = 0
    possible_prizes = 0
    OFFSET = 10000000000000

    lines = input_data.strip().split('\n')

    for i in range(0, len(lines), 4):
        if i + 2 >= len(lines):
            break

        print(f"\nProcessing Machine {i//4 + 1}")

        # Parse input
        a_line = lines[i].strip()
        ax = int(a_line[a_line.find('X+')+2:a_line.find(',')])
        ay = int(a_line[a_line.find('Y+')+2:])

        b_line = lines[i+1].strip()
        bx = int(b_line[b_line.find('X+')+2:b_line.find(',')])
        by = int(b_line[b_line.find('Y+')+2:])

        p_line = lines[i+2].strip()
        px = int(p_line[p_line.find('X=')+2:p_line.find(',')]) + OFFSET
        py = int(p_line[p_line.find('Y=')+2:]) + OFFSET

        print(f"Button A: X+{ax}, Y+{ay}")
        print(f"Button B: X+{bx}, Y+{by}")
        print(f"Prize: X={px}, Y={py}")

        # Find solution
        solution = find_solution(ax, ay, bx, by, px, py)

        if solution:
            n, m = solution
            tokens = 3 * n + m
            total_tokens += tokens
            possible_prizes += 1
            print(f"Solution found for Machine {i//4 + 1}:")
            print(f"Button A presses: {n}")
            print(f"Button B presses: {m}")
            print(f"Tokens needed: {tokens}")
        else:
            print(f"No solution found for Machine {i//4 + 1}")

    return total_tokens, possible_prizes

# Sample input
sample_input = """
Button A: X+97, Y+12
Button B: X+52, Y+63
Prize: X=10471, Y=4350

Button A: X+79, Y+41
Button B: X+29, Y+68
Prize: X=7216, Y=8987

Button A: X+13, Y+68
Button B: X+46, Y+16
Prize: X=1226, Y=8336

Button A: X+14, Y+42
Button B: X+63, Y+23
Prize: X=15649, Y=1769

Button A: X+59, Y+19
Button B: X+53, Y+95
Prize: X=8976, Y=10450

Button A: X+91, Y+84
Button B: X+19, Y+92
Prize: X=9023, Y=13020

Button A: X+14, Y+33
Button B: X+26, Y+12
Prize: X=4032, Y=8054

Button A: X+69, Y+83
Button B: X+70, Y+18
Prize: X=8868, Y=8284

Button A: X+14, Y+47
Button B: X+83, Y+51
Prize: X=7081, Y=7154

Button A: X+33, Y+67
Button B: X+50, Y+17
Prize: X=12916, Y=4279

Button A: X+22, Y+75
Button B: X+77, Y+23
Prize: X=12981, Y=9742

Button A: X+90, Y+30
Button B: X+17, Y+33
Prize: X=6270, Y=2910

Button A: X+62, Y+11
Button B: X+43, Y+65
Prize: X=3850, Y=1601

Button A: X+48, Y+21
Button B: X+21, Y+33
Prize: X=8108, Y=1334

Button A: X+12, Y+40
Button B: X+49, Y+23
Prize: X=12471, Y=11957

Button A: X+86, Y+11
Button B: X+56, Y+69
Prize: X=4404, Y=1058

Button A: X+80, Y+26
Button B: X+11, Y+57
Prize: X=6899, Y=5923

Button A: X+25, Y+51
Button B: X+59, Y+24
Prize: X=14076, Y=10916

Button A: X+48, Y+46
Button B: X+13, Y+94
Prize: X=1915, Y=6320

Button A: X+47, Y+32
Button B: X+20, Y+44
Prize: X=19516, Y=14572

Button A: X+84, Y+21
Button B: X+13, Y+89
Prize: X=4350, Y=2631

Button A: X+29, Y+85
Button B: X+33, Y+26
Prize: X=4361, Y=7973

Button A: X+78, Y+35
Button B: X+11, Y+42
Prize: X=9808, Y=10623

Button A: X+35, Y+64
Button B: X+38, Y+15
Prize: X=4993, Y=274

Button A: X+18, Y+47
Button B: X+54, Y+15
Prize: X=10646, Y=16999

Button A: X+99, Y+55
Button B: X+18, Y+75
Prize: X=5256, Y=5455

Button A: X+83, Y+91
Button B: X+11, Y+58
Prize: X=3635, Y=4261

Button A: X+60, Y+27
Button B: X+29, Y+56
Prize: X=740, Y=11114

Button A: X+59, Y+15
Button B: X+29, Y+75
Prize: X=14539, Y=13025

Button A: X+67, Y+23
Button B: X+11, Y+57
Prize: X=2430, Y=2218

Button A: X+80, Y+45
Button B: X+37, Y+82
Prize: X=9822, Y=10787

Button A: X+11, Y+45
Button B: X+51, Y+23
Prize: X=1269, Y=18697

Button A: X+56, Y+32
Button B: X+16, Y+50
Prize: X=9080, Y=15276

Button A: X+93, Y+93
Button B: X+11, Y+90
Prize: X=4103, Y=11529

Button A: X+24, Y+21
Button B: X+12, Y+51
Prize: X=2016, Y=3627

Button A: X+72, Y+41
Button B: X+25, Y+80
Prize: X=3812, Y=3486

Button A: X+29, Y+14
Button B: X+22, Y+53
Prize: X=2677, Y=14205

Button A: X+56, Y+18
Button B: X+19, Y+69
Prize: X=4292, Y=8432

Button A: X+64, Y+16
Button B: X+14, Y+50
Prize: X=3752, Y=536

Button A: X+45, Y+31
Button B: X+26, Y+59
Prize: X=4694, Y=5247

Button A: X+61, Y+21
Button B: X+19, Y+48
Prize: X=3931, Y=257

Button A: X+13, Y+36
Button B: X+68, Y+26
Prize: X=17218, Y=17896

Button A: X+15, Y+81
Button B: X+31, Y+21
Prize: X=2580, Y=7344

Button A: X+78, Y+51
Button B: X+12, Y+34
Prize: X=3380, Y=16870

Button A: X+86, Y+29
Button B: X+52, Y+60
Prize: X=5118, Y=2745

Button A: X+12, Y+49
Button B: X+77, Y+16
Prize: X=7847, Y=7211

Button A: X+30, Y+49
Button B: X+48, Y+19
Prize: X=1034, Y=15377

Button A: X+25, Y+61
Button B: X+26, Y+12
Prize: X=6825, Y=14177

Button A: X+59, Y+20
Button B: X+11, Y+23
Prize: X=13324, Y=946

Button A: X+36, Y+54
Button B: X+29, Y+13
Prize: X=4435, Y=12219

Button A: X+17, Y+77
Button B: X+61, Y+17
Prize: X=2681, Y=5661

Button A: X+41, Y+19
Button B: X+25, Y+55
Prize: X=4484, Y=9416

Button A: X+26, Y+68
Button B: X+70, Y+26
Prize: X=8284, Y=10434

Button A: X+54, Y+11
Button B: X+25, Y+78
Prize: X=11040, Y=7758

Button A: X+85, Y+23
Button B: X+54, Y+74
Prize: X=2400, Y=2728

Button A: X+93, Y+29
Button B: X+13, Y+22
Prize: X=7293, Y=2328

Button A: X+23, Y+87
Button B: X+48, Y+20
Prize: X=2279, Y=4743

Button A: X+83, Y+34
Button B: X+32, Y+43
Prize: X=7734, Y=4035

Button A: X+25, Y+61
Button B: X+83, Y+44
Prize: X=6884, Y=5225

Button A: X+27, Y+58
Button B: X+98, Y+47
Prize: X=7921, Y=3934

Button A: X+31, Y+57
Button B: X+33, Y+14
Prize: X=3052, Y=3838

Button A: X+96, Y+18
Button B: X+77, Y+97
Prize: X=6503, Y=6751

Button A: X+11, Y+29
Button B: X+71, Y+36
Prize: X=1000, Y=671

Button A: X+25, Y+53
Button B: X+44, Y+20
Prize: X=13129, Y=17325

Button A: X+33, Y+13
Button B: X+50, Y+66
Prize: X=3194, Y=9314

Button A: X+54, Y+15
Button B: X+24, Y+64
Prize: X=19418, Y=8601

Button A: X+13, Y+46
Button B: X+56, Y+14
Prize: X=10671, Y=11208

Button A: X+35, Y+91
Button B: X+25, Y+14
Prize: X=2700, Y=6153

Button A: X+85, Y+25
Button B: X+16, Y+97
Prize: X=2407, Y=1354

Button A: X+24, Y+12
Button B: X+13, Y+30
Prize: X=3299, Y=3318

Button A: X+17, Y+46
Button B: X+50, Y+24
Prize: X=17242, Y=6760

Button A: X+20, Y+43
Button B: X+26, Y+14
Prize: X=2474, Y=748

Button A: X+19, Y+78
Button B: X+90, Y+12
Prize: X=9966, Y=7668

Button A: X+96, Y+77
Button B: X+26, Y+73
Prize: X=3708, Y=5790

Button A: X+37, Y+77
Button B: X+51, Y+15
Prize: X=13364, Y=12440

Button A: X+30, Y+78
Button B: X+76, Y+31
Prize: X=6378, Y=3588

Button A: X+60, Y+26
Button B: X+13, Y+25
Prize: X=10780, Y=7426

Button A: X+33, Y+40
Button B: X+59, Y+16
Prize: X=4212, Y=3440

Button A: X+30, Y+11
Button B: X+25, Y+40
Prize: X=1145, Y=1499

Button A: X+14, Y+30
Button B: X+48, Y+15
Prize: X=4416, Y=3840

Button A: X+45, Y+68
Button B: X+59, Y+25
Prize: X=6633, Y=5404

Button A: X+34, Y+62
Button B: X+44, Y+19
Prize: X=9234, Y=16930

Button A: X+65, Y+12
Button B: X+16, Y+42
Prize: X=13586, Y=10016

Button A: X+16, Y+86
Button B: X+63, Y+54
Prize: X=2515, Y=5264

Button A: X+40, Y+88
Button B: X+91, Y+56
Prize: X=3728, Y=7048

Button A: X+43, Y+79
Button B: X+91, Y+30
Prize: X=5407, Y=1977

Button A: X+87, Y+16
Button B: X+86, Y+76
Prize: X=3366, Y=2244

Button A: X+39, Y+74
Button B: X+94, Y+32
Prize: X=6130, Y=6216

Button A: X+91, Y+50
Button B: X+24, Y+71
Prize: X=9174, Y=7411

Button A: X+81, Y+55
Button B: X+14, Y+95
Prize: X=4359, Y=7320

Button A: X+26, Y+78
Button B: X+79, Y+58
Prize: X=8792, Y=11698

Button A: X+81, Y+58
Button B: X+21, Y+70
Prize: X=8145, Y=9130

Button A: X+29, Y+60
Button B: X+83, Y+29
Prize: X=9583, Y=6839

Button A: X+72, Y+27
Button B: X+23, Y+63
Prize: X=16485, Y=8540

Button A: X+18, Y+30
Button B: X+47, Y+13
Prize: X=3031, Y=8157

Button A: X+36, Y+14
Button B: X+52, Y+70
Prize: X=19584, Y=5184

Button A: X+13, Y+36
Button B: X+32, Y+23
Prize: X=12901, Y=6580

Button A: X+34, Y+66
Button B: X+57, Y+24
Prize: X=13320, Y=4832

Button A: X+79, Y+26
Button B: X+65, Y+85
Prize: X=7528, Y=2732

Button A: X+20, Y+58
Button B: X+96, Y+75
Prize: X=3288, Y=5874

Button A: X+89, Y+24
Button B: X+35, Y+67
Prize: X=3458, Y=5595

Button A: X+63, Y+81
Button B: X+67, Y+22
Prize: X=4988, Y=3206

Button A: X+17, Y+55
Button B: X+54, Y+13
Prize: X=17532, Y=19258

Button A: X+30, Y+94
Button B: X+93, Y+32
Prize: X=2874, Y=4336

Button A: X+31, Y+17
Button B: X+24, Y+40
Prize: X=2311, Y=8105

Button A: X+58, Y+27
Button B: X+19, Y+60
Prize: X=6022, Y=6398

Button A: X+13, Y+67
Button B: X+84, Y+29
Prize: X=2843, Y=2323

Button A: X+56, Y+12
Button B: X+23, Y+81
Prize: X=2380, Y=11120

Button A: X+15, Y+65
Button B: X+56, Y+24
Prize: X=5230, Y=5170

Button A: X+19, Y+47
Button B: X+72, Y+34
Prize: X=17967, Y=11841

Button A: X+16, Y+41
Button B: X+78, Y+60
Prize: X=5144, Y=4789

Button A: X+52, Y+15
Button B: X+16, Y+65
Prize: X=19732, Y=7355

Button A: X+21, Y+81
Button B: X+71, Y+16
Prize: X=17221, Y=9366

Button A: X+61, Y+33
Button B: X+49, Y+87
Prize: X=8507, Y=9381

Button A: X+67, Y+21
Button B: X+15, Y+52
Prize: X=16737, Y=7411

Button A: X+33, Y+49
Button B: X+34, Y+11
Prize: X=6660, Y=4300

Button A: X+19, Y+81
Button B: X+96, Y+33
Prize: X=10734, Y=10392

Button A: X+60, Y+13
Button B: X+63, Y+65
Prize: X=7395, Y=3913

Button A: X+15, Y+21
Button B: X+96, Y+35
Prize: X=6417, Y=3815

Button A: X+20, Y+39
Button B: X+57, Y+27
Prize: X=611, Y=4760

Button A: X+68, Y+97
Button B: X+87, Y+37
Prize: X=11894, Y=9824

Button A: X+13, Y+81
Button B: X+59, Y+12
Prize: X=18946, Y=3392

Button A: X+30, Y+83
Button B: X+57, Y+11
Prize: X=3482, Y=19301

Button A: X+94, Y+11
Button B: X+35, Y+92
Prize: X=11544, Y=7680

Button A: X+45, Y+19
Button B: X+30, Y+45
Prize: X=11315, Y=17659

Button A: X+25, Y+42
Button B: X+79, Y+21
Prize: X=7695, Y=3990

Button A: X+95, Y+91
Button B: X+55, Y+13
Prize: X=10575, Y=9217

Button A: X+27, Y+46
Button B: X+81, Y+26
Prize: X=5508, Y=2776

Button A: X+20, Y+53
Button B: X+29, Y+17
Prize: X=10985, Y=16700

Button A: X+55, Y+74
Button B: X+58, Y+20
Prize: X=8888, Y=8128

Button A: X+40, Y+27
Button B: X+19, Y+43
Prize: X=5535, Y=1095

Button A: X+19, Y+72
Button B: X+54, Y+22
Prize: X=3261, Y=2678

Button A: X+79, Y+39
Button B: X+38, Y+75
Prize: X=7120, Y=6102

Button A: X+26, Y+91
Button B: X+99, Y+25
Prize: X=1223, Y=2673

Button A: X+15, Y+28
Button B: X+58, Y+23
Prize: X=1519, Y=5600

Button A: X+18, Y+53
Button B: X+71, Y+27
Prize: X=11055, Y=3487

Button A: X+14, Y+50
Button B: X+52, Y+18
Prize: X=3908, Y=8576

Button A: X+38, Y+17
Button B: X+23, Y+50
Prize: X=7788, Y=8394

Button A: X+72, Y+20
Button B: X+19, Y+68
Prize: X=10586, Y=4272

Button A: X+28, Y+66
Button B: X+62, Y+12
Prize: X=19418, Y=7934

Button A: X+11, Y+20
Button B: X+49, Y+24
Prize: X=2957, Y=2252

Button A: X+60, Y+11
Button B: X+27, Y+84
Prize: X=3146, Y=1936

Button A: X+18, Y+11
Button B: X+11, Y+41
Prize: X=9360, Y=18112

Button A: X+70, Y+31
Button B: X+15, Y+62
Prize: X=13135, Y=7958

Button A: X+74, Y+35
Button B: X+11, Y+41
Prize: X=19668, Y=14478

Button A: X+53, Y+89
Button B: X+54, Y+23
Prize: X=9521, Y=10100

Button A: X+13, Y+61
Button B: X+68, Y+28
Prize: X=11028, Y=12380

Button A: X+42, Y+29
Button B: X+20, Y+74
Prize: X=1906, Y=1617

Button A: X+44, Y+13
Button B: X+23, Y+60
Prize: X=13690, Y=9554

Button A: X+54, Y+16
Button B: X+11, Y+23
Prize: X=3792, Y=4614

Button A: X+28, Y+11
Button B: X+34, Y+63
Prize: X=13092, Y=15599

Button A: X+61, Y+14
Button B: X+33, Y+73
Prize: X=18520, Y=772

Button A: X+64, Y+29
Button B: X+14, Y+78
Prize: X=3988, Y=4530

Button A: X+18, Y+45
Button B: X+54, Y+26
Prize: X=18170, Y=10118

Button A: X+70, Y+26
Button B: X+11, Y+43
Prize: X=6905, Y=329

Button A: X+72, Y+17
Button B: X+27, Y+58
Prize: X=7461, Y=6253

Button A: X+57, Y+45
Button B: X+18, Y+85
Prize: X=2340, Y=5670

Button A: X+17, Y+81
Button B: X+47, Y+35
Prize: X=5532, Y=8220

Button A: X+14, Y+60
Button B: X+78, Y+22
Prize: X=10172, Y=5672

Button A: X+62, Y+13
Button B: X+17, Y+65
Prize: X=7711, Y=8089

Button A: X+22, Y+38
Button B: X+40, Y+21
Prize: X=15254, Y=15785

Button A: X+83, Y+39
Button B: X+32, Y+71
Prize: X=2416, Y=3038

Button A: X+29, Y+62
Button B: X+68, Y+18
Prize: X=6454, Y=3990

Button A: X+15, Y+38
Button B: X+72, Y+33
Prize: X=3575, Y=8334

Button A: X+81, Y+15
Button B: X+13, Y+83
Prize: X=11268, Y=10108

Button A: X+67, Y+17
Button B: X+12, Y+76
Prize: X=11957, Y=5399

Button A: X+13, Y+97
Button B: X+44, Y+54
Prize: X=2788, Y=7636

Button A: X+14, Y+47
Button B: X+68, Y+30
Prize: X=2678, Y=9911

Button A: X+75, Y+16
Button B: X+22, Y+26
Prize: X=1049, Y=586

Button A: X+16, Y+77
Button B: X+38, Y+25
Prize: X=2368, Y=7607

Button A: X+75, Y+91
Button B: X+77, Y+20
Prize: X=4076, Y=3991

Button A: X+64, Y+19
Button B: X+35, Y+74
Prize: X=8653, Y=7594

Button A: X+33, Y+81
Button B: X+57, Y+15
Prize: X=10661, Y=2849

Button A: X+11, Y+52
Button B: X+70, Y+22
Prize: X=1390, Y=2864

Button A: X+21, Y+40
Button B: X+21, Y+13
Prize: X=5954, Y=5203

Button A: X+52, Y+21
Button B: X+13, Y+64
Prize: X=11131, Y=9958

Button A: X+11, Y+42
Button B: X+95, Y+52
Prize: X=1604, Y=4260

Button A: X+63, Y+13
Button B: X+22, Y+82
Prize: X=670, Y=17610

Button A: X+16, Y+88
Button B: X+84, Y+74
Prize: X=3184, Y=6648

Button A: X+77, Y+14
Button B: X+92, Y+88
Prize: X=13208, Y=8816

Button A: X+63, Y+67
Button B: X+82, Y+13
Prize: X=8310, Y=3940

Button A: X+57, Y+16
Button B: X+17, Y+48
Prize: X=10242, Y=5248

Button A: X+17, Y+72
Button B: X+36, Y+37
Prize: X=3710, Y=5667

Button A: X+69, Y+22
Button B: X+29, Y+54
Prize: X=5207, Y=5330

Button A: X+23, Y+82
Button B: X+49, Y+11
Prize: X=2320, Y=2070

Button A: X+66, Y+27
Button B: X+16, Y+45
Prize: X=11344, Y=9314

Button A: X+56, Y+12
Button B: X+23, Y+66
Prize: X=13879, Y=14258

Button A: X+60, Y+22
Button B: X+18, Y+91
Prize: X=1668, Y=4494

Button A: X+33, Y+11
Button B: X+31, Y+68
Prize: X=6069, Y=13315

Button A: X+14, Y+37
Button B: X+59, Y+14
Prize: X=2210, Y=5344

Button A: X+80, Y+18
Button B: X+33, Y+94
Prize: X=4128, Y=9240

Button A: X+40, Y+17
Button B: X+28, Y+45
Prize: X=3436, Y=3526

Button A: X+16, Y+53
Button B: X+50, Y+22
Prize: X=642, Y=18961

Button A: X+17, Y+39
Button B: X+65, Y+23
Prize: X=9566, Y=11794

Button A: X+66, Y+35
Button B: X+30, Y+76
Prize: X=8010, Y=8394

Button A: X+52, Y+75
Button B: X+37, Y+15
Prize: X=335, Y=19220

Button A: X+36, Y+29
Button B: X+30, Y+89
Prize: X=3690, Y=4334

Button A: X+31, Y+58
Button B: X+50, Y+20
Prize: X=8178, Y=17844

Button A: X+82, Y+22
Button B: X+89, Y+90
Prize: X=4306, Y=1552

Button A: X+12, Y+42
Button B: X+99, Y+75
Prize: X=1173, Y=3291

Button A: X+23, Y+57
Button B: X+40, Y+19
Prize: X=2246, Y=9772

Button A: X+18, Y+42
Button B: X+95, Y+15
Prize: X=9610, Y=4650

Button A: X+20, Y+57
Button B: X+59, Y+21
Prize: X=10072, Y=16868

Button A: X+23, Y+34
Button B: X+42, Y+15
Prize: X=6683, Y=16946

Button A: X+55, Y+73
Button B: X+30, Y+11
Prize: X=4150, Y=3001

Button A: X+22, Y+82
Button B: X+73, Y+12
Prize: X=16713, Y=15870

Button A: X+14, Y+53
Button B: X+65, Y+35
Prize: X=3017, Y=4034

Button A: X+25, Y+53
Button B: X+46, Y+19
Prize: X=13804, Y=8575

Button A: X+29, Y+13
Button B: X+38, Y+60
Prize: X=14048, Y=11678

Button A: X+57, Y+21
Button B: X+61, Y+83
Prize: X=6297, Y=7041

Button A: X+18, Y+99
Button B: X+77, Y+75
Prize: X=2549, Y=3216

Button A: X+59, Y+22
Button B: X+17, Y+33
Prize: X=11044, Y=13465

Button A: X+40, Y+17
Button B: X+47, Y+77
Prize: X=17101, Y=14482

Button A: X+34, Y+14
Button B: X+20, Y+38
Prize: X=594, Y=572

Button A: X+26, Y+62
Button B: X+35, Y+11
Prize: X=6771, Y=8811

Button A: X+20, Y+33
Button B: X+93, Y+21
Prize: X=5259, Y=2982

Button A: X+89, Y+60
Button B: X+13, Y+91
Prize: X=9182, Y=14167

Button A: X+28, Y+98
Button B: X+98, Y+63
Prize: X=5712, Y=8792

Button A: X+67, Y+94
Button B: X+39, Y+15
Prize: X=7520, Y=7532

Button A: X+38, Y+17
Button B: X+25, Y+38
Prize: X=19009, Y=14132

Button A: X+18, Y+51
Button B: X+85, Y+39
Prize: X=9247, Y=7833

Button A: X+40, Y+92
Button B: X+55, Y+23
Prize: X=2390, Y=1978

Button A: X+63, Y+39
Button B: X+24, Y+51
Prize: X=7448, Y=17612

Button A: X+95, Y+25
Button B: X+33, Y+64
Prize: X=11557, Y=8241

Button A: X+40, Y+23
Button B: X+21, Y+73
Prize: X=3186, Y=5853

Button A: X+89, Y+81
Button B: X+13, Y+91
Prize: X=5270, Y=6538

Button A: X+69, Y+17
Button B: X+21, Y+64
Prize: X=10955, Y=8181

Button A: X+59, Y+15
Button B: X+21, Y+77
Prize: X=6203, Y=4791

Button A: X+25, Y+45
Button B: X+36, Y+21
Prize: X=12604, Y=18854

Button A: X+67, Y+17
Button B: X+21, Y+70
Prize: X=7506, Y=17163

Button A: X+78, Y+53
Button B: X+27, Y+89
Prize: X=2391, Y=7065

Button A: X+68, Y+26
Button B: X+23, Y+62
Prize: X=13179, Y=7794

Button A: X+18, Y+44
Button B: X+54, Y+16
Prize: X=18710, Y=4780

Button A: X+16, Y+36
Button B: X+69, Y+48
Prize: X=6028, Y=5412

Button A: X+45, Y+24
Button B: X+34, Y+73
Prize: X=4185, Y=4701

Button A: X+12, Y+26
Button B: X+64, Y+29
Prize: X=8628, Y=3714

Button A: X+53, Y+16
Button B: X+26, Y+65
Prize: X=15387, Y=3502

Button A: X+48, Y+17
Button B: X+49, Y+80
Prize: X=19364, Y=6034

Button A: X+34, Y+70
Button B: X+45, Y+21
Prize: X=3861, Y=2289

Button A: X+39, Y+76
Button B: X+80, Y+14
Prize: X=8169, Y=3574

Button A: X+79, Y+35
Button B: X+45, Y+74
Prize: X=7247, Y=6887

Button A: X+33, Y+19
Button B: X+12, Y+49
Prize: X=7163, Y=16959

Button A: X+24, Y+11
Button B: X+30, Y+49
Prize: X=11852, Y=4499

Button A: X+32, Y+11
Button B: X+25, Y+70
Prize: X=5331, Y=15303

Button A: X+98, Y+63
Button B: X+18, Y+68
Prize: X=5564, Y=5044

Button A: X+85, Y+11
Button B: X+41, Y+76
Prize: X=10558, Y=6527

Button A: X+20, Y+48
Button B: X+45, Y+11
Prize: X=10755, Y=17297

Button A: X+37, Y+23
Button B: X+23, Y+51
Prize: X=12782, Y=14840

Button A: X+37, Y+69
Button B: X+44, Y+11
Prize: X=4057, Y=15396

Button A: X+21, Y+43
Button B: X+55, Y+30
Prize: X=6148, Y=18269

Button A: X+32, Y+63
Button B: X+32, Y+17
Prize: X=8032, Y=16179

Button A: X+81, Y+68
Button B: X+18, Y+51
Prize: X=3429, Y=6001

Button A: X+90, Y+27
Button B: X+36, Y+96
Prize: X=8910, Y=3099

Button A: X+68, Y+36
Button B: X+18, Y+44
Prize: X=494, Y=6740

Button A: X+65, Y+11
Button B: X+13, Y+71
Prize: X=809, Y=7803

Button A: X+29, Y+40
Button B: X+97, Y+24
Prize: X=10076, Y=3248

Button A: X+83, Y+33
Button B: X+17, Y+81
Prize: X=5639, Y=4395

Button A: X+22, Y+33
Button B: X+47, Y+22
Prize: X=7651, Y=1299

Button A: X+58, Y+25
Button B: X+16, Y+31
Prize: X=10590, Y=3747

Button A: X+36, Y+14
Button B: X+36, Y+71
Prize: X=7856, Y=1885

Button A: X+64, Y+18
Button B: X+74, Y+89
Prize: X=9164, Y=5714

Button A: X+82, Y+51
Button B: X+22, Y+99
Prize: X=7542, Y=10407

Button A: X+43, Y+18
Button B: X+34, Y+65
Prize: X=17803, Y=6032

Button A: X+62, Y+39
Button B: X+19, Y+44
Prize: X=15584, Y=11902

Button A: X+32, Y+24
Button B: X+33, Y+83
Prize: X=2199, Y=4853

Button A: X+14, Y+60
Button B: X+80, Y+18
Prize: X=1010, Y=6134

Button A: X+71, Y+24
Button B: X+18, Y+62
Prize: X=3079, Y=5296

Button A: X+17, Y+54
Button B: X+53, Y+12
Prize: X=11314, Y=7550

Button A: X+42, Y+20
Button B: X+13, Y+41
Prize: X=7760, Y=9208

Button A: X+26, Y+48
Button B: X+46, Y+25
Prize: X=16412, Y=3732

Button A: X+20, Y+64
Button B: X+65, Y+21
Prize: X=6165, Y=11225

Button A: X+14, Y+58
Button B: X+68, Y+27
Prize: X=7972, Y=15348

Button A: X+46, Y+17
Button B: X+29, Y+96
Prize: X=3598, Y=8664

Button A: X+93, Y+32
Button B: X+28, Y+76
Prize: X=11382, Y=9292

Button A: X+65, Y+24
Button B: X+11, Y+35
Prize: X=2252, Y=10494

Button A: X+28, Y+61
Button B: X+46, Y+16
Prize: X=14138, Y=7874

Button A: X+49, Y+28
Button B: X+29, Y+66
Prize: X=2640, Y=4672

Button A: X+14, Y+99
Button B: X+98, Y+68
Prize: X=2730, Y=5555

Button A: X+54, Y+54
Button B: X+89, Y+22
Prize: X=5618, Y=3340

Button A: X+18, Y+46
Button B: X+76, Y+48
Prize: X=5930, Y=2346

Button A: X+78, Y+75
Button B: X+87, Y+21
Prize: X=3906, Y=2628

Button A: X+14, Y+22
Button B: X+41, Y+19
Prize: X=3378, Y=12850

Button A: X+69, Y+18
Button B: X+18, Y+73
Prize: X=6411, Y=2697

Button A: X+33, Y+78
Button B: X+70, Y+37
Prize: X=3122, Y=6737

Button A: X+14, Y+74
Button B: X+86, Y+20
Prize: X=6300, Y=2880

Button A: X+11, Y+28
Button B: X+48, Y+11
Prize: X=6804, Y=16815

Button A: X+62, Y+17
Button B: X+31, Y+65
Prize: X=6448, Y=4141

Button A: X+70, Y+11
Button B: X+72, Y+59
Prize: X=4918, Y=1202

Button A: X+97, Y+67
Button B: X+13, Y+33
Prize: X=8935, Y=7805

Button A: X+34, Y+78
Button B: X+76, Y+49
Prize: X=8860, Y=10423

Button A: X+27, Y+69
Button B: X+37, Y+21
Prize: X=1124, Y=960

Button A: X+25, Y+11
Button B: X+15, Y+53
Prize: X=11185, Y=17987

Button A: X+12, Y+57
Button B: X+67, Y+20
Prize: X=10831, Y=11898

Button A: X+21, Y+52
Button B: X+68, Y+37
Prize: X=488, Y=19181

Button A: X+27, Y+12
Button B: X+30, Y+67
Prize: X=4040, Y=8930

Button A: X+84, Y+30
Button B: X+58, Y+99
Prize: X=4462, Y=6369

Button A: X+32, Y+59
Button B: X+37, Y+20
Prize: X=12149, Y=3281

Button A: X+44, Y+12
Button B: X+86, Y+94
Prize: X=7916, Y=8508

Button A: X+11, Y+42
Button B: X+64, Y+29
Prize: X=1438, Y=7055

Button A: X+13, Y+58
Button B: X+71, Y+30
Prize: X=1136, Y=7488

Button A: X+29, Y+32
Button B: X+15, Y+73
Prize: X=466, Y=740

Button A: X+18, Y+40
Button B: X+60, Y+14
Prize: X=3758, Y=16800

Button A: X+29, Y+48
Button B: X+46, Y+11
Prize: X=823, Y=4172

Button A: X+12, Y+36
Button B: X+84, Y+21
Prize: X=2916, Y=1818

Button A: X+57, Y+98
Button B: X+99, Y+38
Prize: X=11955, Y=7862

Button A: X+11, Y+59
Button B: X+54, Y+19
Prize: X=5556, Y=8121

Button A: X+42, Y+16
Button B: X+25, Y+46
Prize: X=6595, Y=7886

Button A: X+18, Y+38
Button B: X+51, Y+33
Prize: X=10826, Y=15950

Button A: X+30, Y+52
Button B: X+24, Y+11
Prize: X=18374, Y=18262

Button A: X+43, Y+17
Button B: X+20, Y+51
Prize: X=6909, Y=5174

Button A: X+12, Y+49
Button B: X+73, Y+35
Prize: X=19520, Y=7473

Button A: X+26, Y+54
Button B: X+81, Y+18
Prize: X=2771, Y=1098

Button A: X+38, Y+16
Button B: X+35, Y+56
Prize: X=9775, Y=16248

Button A: X+74, Y+12
Button B: X+13, Y+83
Prize: X=17184, Y=8706

Button A: X+47, Y+15
Button B: X+59, Y+68
Prize: X=6455, Y=5207

Button A: X+51, Y+75
Button B: X+73, Y+35
Prize: X=3535, Y=4475

Button A: X+11, Y+49
Button B: X+43, Y+19
Prize: X=15272, Y=2282

Button A: X+64, Y+12
Button B: X+12, Y+73
Prize: X=2236, Y=7049

Button A: X+80, Y+36
Button B: X+18, Y+61
Prize: X=19208, Y=11960

Button A: X+52, Y+21
Button B: X+11, Y+35
Prize: X=4204, Y=354


"""

# Run with sample input
print("Running with sample input:")
total_tokens, possible_prizes = solve_claw_machines_part2(sample_input)
print("\nFinal Results:")
print(f"Total possible prizes: {possible_prizes}")
print(f"Total tokens needed: {total_tokens}")
# Out:
# Running with sample input:
#
# Processing Machine 1
# Button A: X+97, Y+12
# Button B: X+52, Y+63
# Prize: X=10000000010471, Y=10000000004350
#
# Solving for equations:
# 97A + 52B = 10000000010471
# 12A + 63B = 10000000004350
# No valid solution: A=20047384806.537815, B=154911609312.24677
# No solution found for Machine 1
#
# Processing Machine 2
# Button A: X+79, Y+41
# Button B: X+29, Y+68
# Prize: X=10000000007216, Y=10000000008987
#
# Solving for equations:
# 79A + 29B = 10000000007216
# 41A + 68B = 10000000008987
# No valid solution: A=93234520733.93857, B=90843892042.58116
# No solution found for Machine 2
#
# Processing Machine 3
# Button A: X+13, Y+68
# Button B: X+46, Y+16
# Prize: X=10000000001226, Y=10000000008336
#
# Solving for equations:
# 13A + 46B = 10000000001226
# 68A + 16B = 10000000008336
# Found solution: A=102739726152, B=188356164375
# Solution found for Machine 3:
# Button A presses: 102739726152
# Button B presses: 188356164375
# Tokens needed: 496575342831
#
# Processing Machine 4
# Button A: X+14, Y+42
# Button B: X+63, Y+23
# Prize: X=10000000015649, Y=10000000001769
#
# Solving for equations:
# 14A + 63B = 10000000015649
# 42A + 23B = 10000000001769
# Found solution: A=172117039480, B=120481927983
# Solution found for Machine 4:
# Button A presses: 172117039480
# Button B presses: 120481927983
# Tokens needed: 636833046423
#
# Processing Machine 5
# Button A: X+59, Y+19
# Button B: X+53, Y+95
# Prize: X=10000000008976, Y=10000000010450
#
# Solving for equations:
# 59A + 53B = 10000000008976
# 19A + 95B = 10000000010450
# No valid solution: A=91344062700.92867, B=86994345464.5511
# No solution found for Machine 5
#
# Processing Machine 6
# Button A: X+91, Y+84
# Button B: X+19, Y+92
# Prize: X=10000000009023, Y=10000000013020
#
# Solving for equations:
# 91A + 19B = 10000000009023
# 84A + 92B = 10000000013020
# No valid solution: A=107733176000.9941, B=10330578575.396694
# No solution found for Machine 6
#
# Processing Machine 7
# Button A: X+14, Y+33
# Button B: X+26, Y+12
# Prize: X=10000000004032, Y=10000000008054
#
# Solving for equations:
# 14A + 26B = 10000000004032
# 33A + 12B = 10000000008054
# Found solution: A=202898550958, B=275362318870
# Solution found for Machine 7:
# Button A presses: 202898550958
# Button B presses: 275362318870
# Tokens needed: 884057971744
#
# Processing Machine 8
# Button A: X+69, Y+83
# Button B: X+70, Y+18
# Prize: X=10000000008868, Y=10000000008284
#
# Solving for equations:
# 69A + 70B = 10000000008868
# 83A + 18B = 10000000008284
# No valid solution: A=113835376624.39929, B=30647986025.49212
# No solution found for Machine 8
#
# Processing Machine 9
# Button A: X+14, Y+47
# Button B: X+83, Y+51
# Prize: X=10000000007081, Y=10000000007154
#
# Solving for equations:
# 14A + 83B = 10000000007081
# 47A + 51B = 10000000007154
# No valid solution: A=100407907195.68591, B=103545654293.26985
# No solution found for Machine 9
#
# Processing Machine 10
# Button A: X+33, Y+67
# Button B: X+50, Y+17
# Prize: X=10000000012916, Y=10000000004279
#
# Solving for equations:
# 33A + 50B = 10000000012916
# 67A + 17B = 10000000004279
# Found solution: A=118321979202, B=121907493985
# Solution found for Machine 10:
# Button A presses: 118321979202
# Button B presses: 121907493985
# Tokens needed: 476873431591
#
# Processing Machine 11
# Button A: X+22, Y+75
# Button B: X+77, Y+23
# Prize: X=10000000012981, Y=10000000009742
#
# Solving for equations:
# 22A + 77B = 10000000012981
# 75A + 23B = 10000000009742
# Found solution: A=102486240359, B=100588347079
# Solution found for Machine 11:
# Button A presses: 102486240359
# Button B presses: 100588347079
# Tokens needed: 408047068156
#
# Processing Machine 12
# Button A: X+90, Y+30
# Button B: X+17, Y+33
# Prize: X=10000000006270, Y=10000000002910
#
# Solving for equations:
# 90A + 17B = 10000000006270
# 30A + 33B = 10000000002910
# No valid solution: A=65040650470.50407, B=243902439054.39026
# No solution found for Machine 12
#
# Processing Machine 13
# Button A: X+62, Y+11
# Button B: X+43, Y+65
# Prize: X=10000000003850, Y=10000000001601
#
# Solving for equations:
# 62A + 43B = 10000000003850
# 11A + 65B = 10000000001601
# No valid solution: A=61849873539.895134, B=143379252194.80237
# No solution found for Machine 13
#
# Processing Machine 14
# Button A: X+48, Y+21
# Button B: X+21, Y+33
# Prize: X=10000000008108, Y=10000000001334
#
# Solving for equations:
# 48A + 21B = 10000000008108
# 21A + 33B = 10000000001334
# Found solution: A=104986876850, B=236220472348
# Solution found for Machine 14:
# Button A presses: 104986876850
# Button B presses: 236220472348
# Tokens needed: 551181102898
#
# Processing Machine 15
# Button A: X+12, Y+40
# Button B: X+49, Y+23
# Prize: X=10000000012471, Y=10000000011957
#
# Solving for equations:
# 12A + 49B = 10000000012471
# 40A + 23B = 10000000011957
# Found solution: A=154394299465, B=166270784059
# Solution found for Machine 15:
# Button A presses: 154394299465
# Button B presses: 166270784059
# Tokens needed: 629453682454
#
# Processing Machine 16
# Button A: X+86, Y+11
# Button B: X+56, Y+69
# Prize: X=10000000004404, Y=10000000001058
#
# Solving for equations:
# 86A + 56B = 10000000004404
# 11A + 69B = 10000000001058
# No valid solution: A=24445280226.518993, B=141030462587.91727
# No solution found for Machine 16
#
# Processing Machine 17
# Button A: X+80, Y+26
# Button B: X+11, Y+57
# Prize: X=10000000006899, Y=10000000005923
#
# Solving for equations:
# 80A + 11B = 10000000006899
# 26A + 57B = 10000000005923
# Found solution: A=107627515285, B=126345344009
# Solution found for Machine 17:
# Button A presses: 107627515285
# Button B presses: 126345344009
# Tokens needed: 449227889864
#
# Processing Machine 18
# Button A: X+25, Y+51
# Button B: X+59, Y+24
# Prize: X=10000000014076, Y=10000000010916
#
# Solving for equations:
# 25A + 59B = 10000000014076
# 51A + 24B = 10000000010916
# Found solution: A=145288501580, B=107928601264
# Solution found for Machine 18:
# Button A presses: 145288501580
# Button B presses: 107928601264
# Tokens needed: 543794106004
#
# Processing Machine 19
# Button A: X+48, Y+46
# Button B: X+13, Y+94
# Prize: X=10000000001915, Y=10000000006320
#
# Solving for equations:
# 48A + 13B = 10000000001915
# 46A + 94B = 10000000006320
# No valid solution: A=206949412390.86612, B=5109862088.725089
# No solution found for Machine 19
#
# Processing Machine 20
# Button A: X+47, Y+32
# Button B: X+20, Y+44
# Prize: X=10000000019516, Y=10000000014572
#
# Solving for equations:
# 47A + 20B = 10000000019516
# 32A + 44B = 10000000014572
# Found solution: A=168067227288, B=105042016849
# Solution found for Machine 20:
# Button A presses: 168067227288
# Button B presses: 105042016849
# Tokens needed: 609243698713
#
# Processing Machine 21
# Button A: X+84, Y+21
# Button B: X+13, Y+89
# Prize: X=10000000004350, Y=10000000002631
#
# Solving for equations:
# 84A + 13B = 10000000004350
# 21A + 89B = 10000000002631
# No valid solution: A=105511592441.05887, B=87463556869.31195
# No solution found for Machine 21
#
# Processing Machine 22
# Button A: X+29, Y+85
# Button B: X+33, Y+26
# Prize: X=10000000004361, Y=10000000007973
#
# Solving for equations:
# 29A + 33B = 10000000004361
# 85A + 26B = 10000000007973
# No valid solution: A=34129692905.764503, B=273037542730.11603
# No solution found for Machine 22
#
# Processing Machine 23
# Button A: X+78, Y+35
# Button B: X+11, Y+42
# Prize: X=10000000009808, Y=10000000010623
#
# Solving for equations:
# 78A + 11B = 10000000009808
# 35A + 42B = 10000000010623
# Found solution: A=107229332513, B=148737461254
# Solution found for Machine 23:
# Button A presses: 107229332513
# Button B presses: 148737461254
# Tokens needed: 470425458793
#
# Processing Machine 24
# Button A: X+35, Y+64
# Button B: X+38, Y+15
# Prize: X=10000000004993, Y=10000000000274
#
# Solving for equations:
# 35A + 38B = 10000000004993
# 64A + 15B = 10000000000274
# Found solution: A=120608285231, B=152071316366
# Solution found for Machine 24:
# Button A presses: 120608285231
# Button B presses: 152071316366
# Tokens needed: 513896172059
#
# Processing Machine 25
# Button A: X+18, Y+47
# Button B: X+54, Y+15
# Prize: X=10000000010646, Y=10000000016999
#
# Solving for equations:
# 18A + 54B = 10000000010646
# 47A + 15B = 10000000016999
# Found solution: A=171957672292, B=127865961285
# Solution found for Machine 25:
# Button A presses: 171957672292
# Button B presses: 127865961285
# Tokens needed: 643738978161
#
# Processing Machine 26
# Button A: X+99, Y+55
# Button B: X+18, Y+75
# Prize: X=10000000005256, Y=10000000005455
#
# Solving for equations:
# 99A + 18B = 10000000005256
# 55A + 75B = 10000000005455
# No valid solution: A=88578088624.08858, B=68376068415.068375
# No solution found for Machine 26
#
# Processing Machine 27
# Button A: X+83, Y+91
# Button B: X+11, Y+58
# Prize: X=10000000003635, Y=10000000004261
#
# Solving for equations:
# 83A + 11B = 10000000003635
# 91A + 58B = 10000000004261
# No valid solution: A=123262522990.81012, B=-20980854963.84002
# No solution found for Machine 27
#
# Processing Machine 28
# Button A: X+60, Y+27
# Button B: X+29, Y+56
# Prize: X=10000000000740, Y=10000000011114
#
# Solving for equations:
# 60A + 29B = 10000000000740
# 27A + 56B = 10000000011114
# Found solution: A=104772991742, B=128055879180
# Solution found for Machine 28:
# Button A presses: 104772991742
# Button B presses: 128055879180
# Tokens needed: 442374854406
#
# Processing Machine 29
# Button A: X+59, Y+15
# Button B: X+29, Y+75
# Prize: X=10000000014539, Y=10000000013025
#
# Solving for equations:
# 59A + 29B = 10000000014539
# 15A + 75B = 10000000013025
# Found solution: A=115288220730, B=110275689361
# Solution found for Machine 29:
# Button A presses: 115288220730
# Button B presses: 110275689361
# Tokens needed: 456140351551
#
# Processing Machine 30
# Button A: X+67, Y+23
# Button B: X+11, Y+57
# Prize: X=10000000002430, Y=10000000002218
#
# Solving for equations:
# 67A + 11B = 10000000002430
# 23A + 57B = 10000000002218
# No valid solution: A=128996074064.52945, B=123387549100.59338
# No solution found for Machine 30
#
# Processing Machine 31
# Button A: X+80, Y+45
# Button B: X+37, Y+82
# Prize: X=10000000009822, Y=10000000010787
#
# Solving for equations:
# 80A + 37B = 10000000009822
# 45A + 82B = 10000000010787
# No valid solution: A=91930541451.74362, B=71501532261.68948
# No solution found for Machine 31
#
# Processing Machine 32
# Button A: X+11, Y+45
# Button B: X+51, Y+23
# Prize: X=10000000001269, Y=10000000018697
#
# Solving for equations:
# 11A + 51B = 10000000001269
# 45A + 23B = 10000000018697
# Found solution: A=137120470580, B=166503427939
# Solution found for Machine 32:
# Button A presses: 137120470580
# Button B presses: 166503427939
# Tokens needed: 577864839679
#
# Processing Machine 33
# Button A: X+56, Y+32
# Button B: X+16, Y+50
# Prize: X=10000000009080, Y=10000000015276
#
# Solving for equations:
# 56A + 16B = 10000000009080
# 32A + 50B = 10000000015276
# Found solution: A=148601398693, B=104895105142
# Solution found for Machine 33:
# Button A presses: 148601398693
# Button B presses: 104895105142
# Tokens needed: 550699301221
#
# Processing Machine 34
# Button A: X+93, Y+93
# Button B: X+11, Y+90
# Prize: X=10000000004103, Y=10000000011529
#
# Solving for equations:
# 93A + 11B = 10000000004103
# 93A + 90B = 10000000011529
# No valid solution: A=107526881753.43011, B=94.0
# No solution found for Machine 34
#
# Processing Machine 35
# Button A: X+24, Y+21
# Button B: X+12, Y+51
# Prize: X=10000000002016, Y=10000000003627
#
# Solving for equations:
# 24A + 12B = 10000000002016
# 21A + 51B = 10000000003627
# No valid solution: A=401234567962.23456, B=30864197576.864197
# No solution found for Machine 35
#
# Processing Machine 36
# Button A: X+72, Y+41
# Button B: X+25, Y+80
# Prize: X=10000000003812, Y=10000000003486
#
# Solving for equations:
# 72A + 25B = 10000000003812
# 41A + 80B = 10000000003486
# No valid solution: A=116156283044.94403, B=65469904983.04118
# No solution found for Machine 36
#
# Processing Machine 37
# Button A: X+29, Y+14
# Button B: X+22, Y+53
# Prize: X=10000000002677, Y=10000000014205
#
# Solving for equations:
# 29A + 22B = 10000000002677
# 14A + 53B = 10000000014205
# Found solution: A=252237591399, B=122050447823
# Solution found for Machine 37:
# Button A presses: 252237591399
# Button B presses: 122050447823
# Tokens needed: 878763222020
#
# Processing Machine 38
# Button A: X+56, Y+18
# Button B: X+19, Y+69
# Prize: X=10000000004292, Y=10000000008432
#
# Solving for equations:
# 56A + 19B = 10000000004292
# 18A + 69B = 10000000008432
# Found solution: A=141964792770, B=107893242588
# Solution found for Machine 38:
# Button A presses: 141964792770
# Button B presses: 107893242588
# Tokens needed: 533787620898
#
# Processing Machine 39
# Button A: X+64, Y+16
# Button B: X+14, Y+50
# Prize: X=10000000003752, Y=10000000000536
#
# Solving for equations:
# 64A + 14B = 10000000003752
# 16A + 50B = 10000000000536
# Found solution: A=120967741996, B=161290322572
# Solution found for Machine 39:
# Button A presses: 120967741996
# Button B presses: 161290322572
# Tokens needed: 524193548560
#
# Processing Machine 40
# Button A: X+45, Y+31
# Button B: X+26, Y+59
# Prize: X=10000000004694, Y=10000000005247
#
# Solving for equations:
# 45A + 26B = 10000000004694
# 31A + 59B = 10000000005247
# No valid solution: A=178474851346.95728, B=75716603618.49702
# No solution found for Machine 40
#
# Processing Machine 41
# Button A: X+61, Y+21
# Button B: X+19, Y+48
# Prize: X=10000000003931, Y=10000000000257
#
# Solving for equations:
# 61A + 19B = 10000000003931
# 21A + 48B = 10000000000257
# Found solution: A=114669830045, B=158165282694
# Solution found for Machine 41:
# Button A presses: 114669830045
# Button B presses: 158165282694
# Tokens needed: 502174772829
#
# Processing Machine 42
# Button A: X+13, Y+36
# Button B: X+68, Y+26
# Prize: X=10000000017218, Y=10000000017896
#
# Solving for equations:
# 13A + 68B = 10000000017218
# 36A + 26B = 10000000017896
# Found solution: A=199052133066, B=109004739520
# Solution found for Machine 42:
# Button A presses: 199052133066
# Button B presses: 109004739520
# Tokens needed: 706161138718
#
# Processing Machine 43
# Button A: X+15, Y+81
# Button B: X+31, Y+21
# Prize: X=10000000002580, Y=10000000007344
#
# Solving for equations:
# 15A + 31B = 10000000002580
# 81A + 21B = 10000000007344
# No valid solution: A=45537340698.30783, B=300546448132.4317
# No solution found for Machine 43
#
# Processing Machine 44
# Button A: X+78, Y+51
# Button B: X+12, Y+34
# Prize: X=10000000003380, Y=10000000016870
#
# Solving for equations:
# 78A + 12B = 10000000003380
# 51A + 34B = 10000000016870
# Found solution: A=107843137212, B=132352941737
# Solution found for Machine 44:
# Button A presses: 107843137212
# Button B presses: 132352941737
# Tokens needed: 455882353373
#
# Processing Machine 45
# Button A: X+86, Y+29
# Button B: X+52, Y+60
# Prize: X=10000000005118, Y=10000000002745
#
# Solving for equations:
# 86A + 52B = 10000000005118
# 29A + 60B = 10000000002745
# No valid solution: A=21905805083.33516, B=156078860922.138
# No solution found for Machine 45
#
# Processing Machine 46
# Button A: X+12, Y+49
# Button B: X+77, Y+16
# Prize: X=10000000007847, Y=10000000007211
#
# Solving for equations:
# 12A + 77B = 10000000007847
# 49A + 16B = 10000000007211
# Found solution: A=170343479595, B=103323094191
# Solution found for Machine 46:
# Button A presses: 170343479595
# Button B presses: 103323094191
# Tokens needed: 614353532976
#
# Processing Machine 47
# Button A: X+30, Y+49
# Button B: X+48, Y+19
# Prize: X=10000000001034, Y=10000000015377
#
# Solving for equations:
# 30A + 48B = 10000000001034
# 49A + 19B = 10000000015377
# Found solution: A=162738496475, B=106621773058
# Solution found for Machine 47:
# Button A presses: 162738496475
# Button B presses: 106621773058
# Tokens needed: 594837262483
#
# Processing Machine 48
# Button A: X+25, Y+61
# Button B: X+26, Y+12
# Prize: X=10000000006825, Y=10000000014177
#
# Solving for equations:
# 25A + 26B = 10000000006825
# 61A + 12B = 10000000014177
# Found solution: A=108864696957, B=279937791650
# Solution found for Machine 48:
# Button A presses: 108864696957
# Button B presses: 279937791650
# Tokens needed: 606531882521
#
# Processing Machine 49
# Button A: X+59, Y+20
# Button B: X+11, Y+23
# Prize: X=10000000013324, Y=10000000000946
#
# Solving for equations:
# 59A + 11B = 10000000013324
# 20A + 23B = 10000000000946
# Found solution: A=105540897358, B=343007915382
# Solution found for Machine 49:
# Button A presses: 105540897358
# Button B presses: 343007915382
# Tokens needed: 659630607456
#
# Processing Machine 50
# Button A: X+36, Y+54
# Button B: X+29, Y+13
# Prize: X=10000000004435, Y=10000000012219
#
# Solving for equations:
# 36A + 29B = 10000000004435
# 54A + 13B = 10000000012219
# Found solution: A=145719490252, B=163934426047
# Solution found for Machine 50:
# Button A presses: 145719490252
# Button B presses: 163934426047
# Tokens needed: 601092896803
#
# Processing Machine 51
# Button A: X+17, Y+77
# Button B: X+61, Y+17
# Prize: X=10000000002681, Y=10000000005661
#
# Solving for equations:
# 17A + 61B = 10000000002681
# 77A + 17B = 10000000005661
# No valid solution: A=99818511864.73322, B=136116152475.09074
# No solution found for Machine 51
#
# Processing Machine 52
# Button A: X+41, Y+19
# Button B: X+25, Y+55
# Prize: X=10000000004484, Y=10000000009416
#
# Solving for equations:
# 41A + 25B = 10000000004484
# 19A + 55B = 10000000009416
# Found solution: A=168539325849, B=123595505787
# Solution found for Machine 52:
# Button A presses: 168539325849
# Button B presses: 123595505787
# Tokens needed: 629213483334
#
# Processing Machine 53
# Button A: X+26, Y+68
# Button B: X+70, Y+26
# Prize: X=10000000008284, Y=10000000010434
#
# Solving for equations:
# 26A + 70B = 10000000008284
# 68A + 26B = 10000000010434
# Found solution: A=107737512369, B=102840352667
# Solution found for Machine 53:
# Button A presses: 107737512369
# Button B presses: 102840352667
# Tokens needed: 426052889774
#
# Processing Machine 54
# Button A: X+54, Y+11
# Button B: X+25, Y+78
# Prize: X=10000000011040, Y=10000000007758
#
# Solving for equations:
# 54A + 25B = 10000000011040
# 11A + 78B = 10000000007758
# Found solution: A=134620269410, B=109220218516
# Solution found for Machine 54:
# Button A presses: 134620269410
# Button B presses: 109220218516
# Tokens needed: 513081026746
#
# Processing Machine 55
# Button A: X+85, Y+23
# Button B: X+54, Y+74
# Prize: X=10000000002400, Y=10000000002728
#
# Solving for equations:
# 85A + 54B = 10000000002400
# 23A + 74B = 10000000002728
# No valid solution: A=39619651353.068146, B=122820919210.91125
# No solution found for Machine 55
#
# Processing Machine 56
# Button A: X+93, Y+29
# Button B: X+13, Y+22
# Prize: X=10000000007293, Y=10000000002328
#
# Solving for equations:
# 93A + 13B = 10000000007293
# 29A + 22B = 10000000002328
# No valid solution: A=53924505770.03116, B=383463151590.7771
# No solution found for Machine 56
#
# Processing Machine 57
# Button A: X+23, Y+87
# Button B: X+48, Y+20
# Prize: X=10000000002279, Y=10000000004743
#
# Solving for equations:
# 23A + 48B = 10000000002279
# 87A + 20B = 10000000004743
# No valid solution: A=75349838585.06029, B=172228202392.1378
# No solution found for Machine 57
#
# Processing Machine 58
# Button A: X+83, Y+34
# Button B: X+32, Y+43
# Prize: X=10000000007734, Y=10000000004035
#
# Solving for equations:
# 83A + 32B = 10000000007734
# 34A + 43B = 10000000004035
# No valid solution: A=44336960984.86175, B=197501007687.20233
# No solution found for Machine 58
#
# Processing Machine 59
# Button A: X+25, Y+61
# Button B: X+83, Y+44
# Prize: X=10000000006884, Y=10000000005225
#
# Solving for equations:
# 25A + 83B = 10000000006884
# 61A + 44B = 10000000005225
# No valid solution: A=98410295263.8857, B=90840272593.81757
# No solution found for Machine 59
#
# Processing Machine 60
# Button A: X+27, Y+58
# Button B: X+98, Y+47
# Prize: X=10000000007921, Y=10000000003934
#
# Solving for equations:
# 27A + 98B = 10000000007921
# 58A + 47B = 10000000003934
# No valid solution: A=115515288791.22197, B=70215175617.93884
# No solution found for Machine 60
#
# Processing Machine 61
# Button A: X+31, Y+57
# Button B: X+33, Y+14
# Prize: X=10000000003052, Y=10000000003838
#
# Solving for equations:
# 31A + 33B = 10000000003052
# 57A + 14B = 10000000003838
# No valid solution: A=131306150714.53075, B=179682100936.4105
# No solution found for Machine 61
#
# Processing Machine 62
# Button A: X+96, Y+18
# Button B: X+77, Y+97
# Prize: X=10000000006503, Y=10000000006751
#
# Solving for equations:
# 96A + 77B = 10000000006503
# 18A + 97B = 10000000006751
# No valid solution: A=25233409047.560432, B=98410295297.8857
# No solution found for Machine 62
#
# Processing Machine 63
# Button A: X+11, Y+29
# Button B: X+71, Y+36
# Prize: X=10000000001000, Y=10000000000671
#
# Solving for equations:
# 11A + 71B = 10000000001000
# 29A + 36B = 10000000000671
# No valid solution: A=210463018648.01022, B=108238123885.51955
# No solution found for Machine 63
#
# Processing Machine 64
# Button A: X+25, Y+53
# Button B: X+44, Y+20
# Prize: X=10000000013129, Y=10000000017325
#
# Solving for equations:
# 25A + 44B = 10000000013129
# 53A + 20B = 10000000017325
# Found solution: A=131004367085, B=152838428091
# Solution found for Machine 64:
# Button A presses: 131004367085
# Button B presses: 152838428091
# Tokens needed: 545851529346
#
# Processing Machine 65
# Button A: X+33, Y+13
# Button B: X+50, Y+66
# Prize: X=10000000003194, Y=10000000009314
#
# Solving for equations:
# 33A + 50B = 10000000003194
# 13A + 66B = 10000000009314
# Found solution: A=104712041718, B=130890052530
# Solution found for Machine 65:
# Button A presses: 104712041718
# Button B presses: 130890052530
# Tokens needed: 445026177684
#
# Processing Machine 66
# Button A: X+54, Y+15
# Button B: X+24, Y+64
# Prize: X=10000000019418, Y=10000000008601
#
# Solving for equations:
# 54A + 24B = 10000000019418
# 15A + 64B = 10000000008601
# Found solution: A=129198966743, B=125968992304
# Solution found for Machine 66:
# Button A presses: 129198966743
# Button B presses: 125968992304
# Tokens needed: 513565892533
#
# Processing Machine 67
# Button A: X+13, Y+46
# Button B: X+56, Y+14
# Prize: X=10000000010671, Y=10000000011208
#
# Solving for equations:
# 13A + 56B = 10000000010671
# 46A + 14B = 10000000011208
# Found solution: A=175438596691, B=137844611673
# Solution found for Machine 67:
# Button A presses: 175438596691
# Button B presses: 137844611673
# Tokens needed: 664160401746
#
# Processing Machine 68
# Button A: X+35, Y+91
# Button B: X+25, Y+14
# Prize: X=10000000002700, Y=10000000006153
#
# Solving for equations:
# 35A + 25B = 10000000002700
# 91A + 14B = 10000000006153
# No valid solution: A=61624649924.94398, B=313725490213.0784
# No solution found for Machine 68
#
# Processing Machine 69
# Button A: X+85, Y+25
# Button B: X+16, Y+97
# Prize: X=10000000002407, Y=10000000001354
#
# Solving for equations:
# 85A + 16B = 10000000002407
# 25A + 97B = 10000000001354
# No valid solution: A=103250478038.47227, B=76481835571.05354
# No solution found for Machine 69
#
# Processing Machine 70
# Button A: X+24, Y+12
# Button B: X+13, Y+30
# Prize: X=10000000003299, Y=10000000003318
#
# Solving for equations:
# 24A + 13B = 10000000003299
# 12A + 30B = 10000000003318
# No valid solution: A=301418439815.3121, B=212765957517.8085
# No solution found for Machine 70
#
# Processing Machine 71
# Button A: X+17, Y+46
# Button B: X+50, Y+24
# Prize: X=10000000017242, Y=10000000006760
#
# Solving for equations:
# 17A + 50B = 10000000017242
# 46A + 24B = 10000000006760
# Found solution: A=137420718776, B=153276955961
# Solution found for Machine 71:
# Button A presses: 137420718776
# Button B presses: 153276955961
# Tokens needed: 565539112289
#
# Processing Machine 72
# Button A: X+20, Y+43
# Button B: X+26, Y+14
# Prize: X=10000000002474, Y=10000000000748
#
# Solving for equations:
# 20A + 26B = 10000000002474
# 43A + 14B = 10000000000748
# Found solution: A=143198090674, B=274463007269
# Solution found for Machine 72:
# Button A presses: 143198090674
# Button B presses: 274463007269
# Tokens needed: 704057279291
#
# Processing Machine 73
# Button A: X+19, Y+78
# Button B: X+90, Y+12
# Prize: X=10000000009966, Y=10000000007668
#
# Solving for equations:
# 19A + 90B = 10000000009966
# 78A + 12B = 10000000007668
# No valid solution: A=114840989483.29329, B=86866902330.92697
# No solution found for Machine 73
#
# Processing Machine 74
# Button A: X+96, Y+77
# Button B: X+26, Y+73
# Prize: X=10000000003708, Y=10000000005790
#
# Solving for equations:
# 96A + 26B = 10000000003708
# 77A + 73B = 10000000005790
# No valid solution: A=93887335221.76268, B=37954454708.4147
# No solution found for Machine 74
#
# Processing Machine 75
# Button A: X+37, Y+77
# Button B: X+51, Y+15
# Prize: X=10000000013364, Y=10000000012440
#
# Solving for equations:
# 37A + 51B = 10000000013364
# 77A + 15B = 10000000012440
# Found solution: A=106761565965, B=118623962209
# Solution found for Machine 75:
# Button A presses: 106761565965
# Button B presses: 118623962209
# Tokens needed: 438908660104
#
# Processing Machine 76
# Button A: X+30, Y+78
# Button B: X+76, Y+31
# Prize: X=10000000006378, Y=10000000003588
#
# Solving for equations:
# 30A + 76B = 10000000006378
# 78A + 31B = 10000000003588
# No valid solution: A=90036014420.7623, B=96038415444.14645
# No solution found for Machine 76
#
# Processing Machine 77
# Button A: X+60, Y+26
# Button B: X+13, Y+25
# Prize: X=10000000010780, Y=10000000007426
#
# Solving for equations:
# 60A + 13B = 10000000010780
# 26A + 25B = 10000000007426
# Found solution: A=103270223901, B=292598967440
# Solution found for Machine 77:
# Button A presses: 103270223901
# Button B presses: 292598967440
# Tokens needed: 602409639143
#
# Processing Machine 78
# Button A: X+33, Y+40
# Button B: X+59, Y+16
# Prize: X=10000000004212, Y=10000000003440
#
# Solving for equations:
# 33A + 59B = 10000000004212
# 40A + 16B = 10000000003440
# No valid solution: A=234716157279.24017, B=38209607016.89957
# No solution found for Machine 78
#
# Processing Machine 79
# Button A: X+30, Y+11
# Button B: X+25, Y+40
# Prize: X=10000000001145, Y=10000000001499
#
# Solving for equations:
# 30A + 25B = 10000000001145
# 11A + 40B = 10000000001499
# No valid solution: A=162162162171.16217, B=205405405440.4054
# No solution found for Machine 79
#
# Processing Machine 80
# Button A: X+14, Y+30
# Button B: X+48, Y+15
# Prize: X=10000000004416, Y=10000000003840
#
# Solving for equations:
# 14A + 48B = 10000000004416
# 30A + 15B = 10000000003840
# No valid solution: A=268292683022.82925, B=130081300877.00813
# No solution found for Machine 80
#
# Processing Machine 81
# Button A: X+45, Y+68
# Button B: X+59, Y+25
# Prize: X=10000000006633, Y=10000000005404
#
# Solving for equations:
# 45A + 59B = 10000000006633
# 68A + 25B = 10000000005404
# No valid solution: A=117769310756.15205, B=79667474959.42639
# No solution found for Machine 81
#
# Processing Machine 82
# Button A: X+34, Y+62
# Button B: X+44, Y+19
# Prize: X=10000000009234, Y=10000000016930
#
# Solving for equations:
# 34A + 44B = 10000000009234
# 62A + 19B = 10000000016930
# Found solution: A=120076849457, B=134486071084
# Solution found for Machine 82:
# Button A presses: 120076849457
# Button B presses: 134486071084
# Tokens needed: 494716619455
#
# Processing Machine 83
# Button A: X+65, Y+12
# Button B: X+16, Y+42
# Prize: X=10000000013586, Y=10000000010016
#
# Solving for equations:
# 65A + 16B = 10000000013586
# 12A + 42B = 10000000010016
# Found solution: A=102442868562, B=208825847316
# Solution found for Machine 83:
# Button A presses: 102442868562
# Button B presses: 208825847316
# Tokens needed: 516154453002
#
# Processing Machine 84
# Button A: X+16, Y+86
# Button B: X+63, Y+54
# Prize: X=10000000002515, Y=10000000005264
#
# Solving for equations:
# 16A + 63B = 10000000002515
# 86A + 54B = 10000000005264
# No valid solution: A=19762845892.802372, B=153711023305.24066
# No solution found for Machine 84
#
# Processing Machine 85
# Button A: X+40, Y+88
# Button B: X+91, Y+56
# Prize: X=10000000003728, Y=10000000007048
#
# Solving for equations:
# 40A + 91B = 10000000003728
# 88A + 56B = 10000000007048
# No valid solution: A=60679611725.485435, B=83217753128.66574
# No solution found for Machine 85
#
# Processing Machine 86
# Button A: X+43, Y+79
# Button B: X+91, Y+30
# Prize: X=10000000005407, Y=10000000001977
#
# Solving for equations:
# 43A + 91B = 10000000005407
# 79A + 30B = 10000000001977
# No valid solution: A=103407357182.1829, B=61027292819.485
# No solution found for Machine 86
#
# Processing Machine 87
# Button A: X+87, Y+16
# Button B: X+86, Y+76
# Prize: X=10000000003366, Y=10000000002244
#
# Solving for equations:
# 87A + 86B = 10000000003366
# 16A + 76B = 10000000002244
# No valid solution: A=-19098548498.313217, B=135599694450.22383
# No solution found for Machine 87
#
# Processing Machine 88
# Button A: X+39, Y+74
# Button B: X+94, Y+32
# Prize: X=10000000006130, Y=10000000006216
#
# Solving for equations:
# 39A + 94B = 10000000006130
# 74A + 32B = 10000000006216
# No valid solution: A=108619481497.57253, B=61317449231.113525
# No solution found for Machine 88
#
# Processing Machine 89
# Button A: X+91, Y+50
# Button B: X+24, Y+71
# Prize: X=10000000009174, Y=10000000007411
#
# Solving for equations:
# 91A + 24B = 10000000009174
# 50A + 71B = 10000000007411
# No valid solution: A=89336628107.48717, B=77931952141.36115
# No solution found for Machine 89
#
# Processing Machine 90
# Button A: X+81, Y+55
# Button B: X+14, Y+95
# Prize: X=10000000004359, Y=10000000007320
#
# Solving for equations:
# 81A + 14B = 10000000004359
# 55A + 95B = 10000000007320
# No valid solution: A=116967509070.27075, B=37545126404.79061
# No solution found for Machine 90
#
# Processing Machine 91
# Button A: X+26, Y+78
# Button B: X+79, Y+58
# Prize: X=10000000008792, Y=10000000011698
#
# Solving for equations:
# 26A + 79B = 10000000008792
# 78A + 58B = 10000000011698
# No valid solution: A=45122475379.07306, B=111731843657.41899
# No solution found for Machine 91
#
# Processing Machine 92
# Button A: X+81, Y+58
# Button B: X+21, Y+70
# Prize: X=10000000008145, Y=10000000009130
#
# Solving for equations:
# 81A + 21B = 10000000008145
# 58A + 70B = 10000000009130
# No valid solution: A=110062893166.761, B=51662174363.68374
# No solution found for Machine 92
#
# Processing Machine 93
# Button A: X+29, Y+60
# Button B: X+83, Y+29
# Prize: X=10000000009583, Y=10000000006839
#
# Solving for equations:
# 29A + 83B = 10000000009583
# 60A + 29B = 10000000006839
# No valid solution: A=130466296276.81323, B=74897318283.80019
# No solution found for Machine 93
#
# Processing Machine 94
# Button A: X+72, Y+27
# Button B: X+23, Y+63
# Prize: X=10000000016485, Y=10000000008540
#
# Solving for equations:
# 72A + 23B = 10000000016485
# 27A + 63B = 10000000008540
# Found solution: A=102171136869, B=114942528779
# Solution found for Machine 94:
# Button A presses: 102171136869
# Button B presses: 114942528779
# Tokens needed: 421455939386
#
# Processing Machine 95
# Button A: X+18, Y+30
# Button B: X+47, Y+13
# Prize: X=10000000003031, Y=10000000008157
#
# Solving for equations:
# 18A + 47B = 10000000003031
# 30A + 13B = 10000000008157
# Found solution: A=289115646551, B=102040816279
# Solution found for Machine 95:
# Button A presses: 289115646551
# Button B presses: 102040816279
# Tokens needed: 969387755932
#
# Processing Machine 96
# Button A: X+36, Y+14
# Button B: X+52, Y+70
# Prize: X=10000000019584, Y=10000000005184
#
# Solving for equations:
# 36A + 52B = 10000000019584
# 14A + 70B = 10000000005184
# Found solution: A=100446429186, B=122767857094
# Solution found for Machine 96:
# Button A presses: 100446429186
# Button B presses: 122767857094
# Tokens needed: 424107144652
#
# Processing Machine 97
# Button A: X+13, Y+36
# Button B: X+32, Y+23
# Prize: X=10000000012901, Y=10000000006580
#
# Solving for equations:
# 13A + 32B = 10000000012901
# 36A + 23B = 10000000006580
# Found solution: A=105509964729, B=269636577232
# Solution found for Machine 97:
# Button A presses: 105509964729
# Button B presses: 269636577232
# Tokens needed: 586166471419
#
# Processing Machine 98
# Button A: X+34, Y+66
# Button B: X+57, Y+24
# Prize: X=10000000013320, Y=10000000004832
#
# Solving for equations:
# 34A + 57B = 10000000013320
# 66A + 24B = 10000000004832
# Found solution: A=112016293264, B=108621860392
# Solution found for Machine 98:
# Button A presses: 112016293264
# Button B presses: 108621860392
# Tokens needed: 444670740184
#
# Processing Machine 99
# Button A: X+79, Y+26
# Button B: X+65, Y+85
# Prize: X=10000000007528, Y=10000000002732
#
# Solving for equations:
# 79A + 65B = 10000000007528
# 26A + 85B = 10000000002732
# No valid solution: A=39800995116.875626, B=105472636819.9204
# No solution found for Machine 99
#
# Processing Machine 100
# Button A: X+20, Y+58
# Button B: X+96, Y+75
# Prize: X=10000000003288, Y=10000000005874
#
# Solving for equations:
# 20A + 96B = 10000000003288
# 58A + 75B = 10000000005874
# No valid solution: A=51622418957.056046, B=93411996084.86333
# No solution found for Machine 100
#
# Processing Machine 101
# Button A: X+89, Y+24
# Button B: X+35, Y+67
# Prize: X=10000000003458, Y=10000000005595
#
# Solving for equations:
# 89A + 35B = 10000000003458
# 24A + 67B = 10000000005595
# No valid solution: A=62463400358.35663, B=126878782044.69315
# No solution found for Machine 101
#
# Processing Machine 102
# Button A: X+63, Y+81
# Button B: X+67, Y+22
# Prize: X=10000000004988, Y=10000000003206
#
# Solving for equations:
# 63A + 67B = 10000000004988
# 81A + 22B = 10000000003206
# No valid solution: A=111358574636.245, B=44543429894.09799
# No solution found for Machine 102
#
# Processing Machine 103
# Button A: X+17, Y+55
# Button B: X+54, Y+13
# Prize: X=10000000017532, Y=10000000019258
#
# Solving for equations:
# 17A + 54B = 10000000017532
# 55A + 13B = 10000000019258
# Found solution: A=149145143984, B=138232084626
# Solution found for Machine 103:
# Button A presses: 149145143984
# Button B presses: 138232084626
# Tokens needed: 585667516578
#
# Processing Machine 104
# Button A: X+30, Y+94
# Button B: X+93, Y+32
# Prize: X=10000000002874, Y=10000000004336
#
# Solving for equations:
# 30A + 93B = 10000000002874
# 94A + 32B = 10000000004336
# No valid solution: A=78386019058.24724, B=82241069151.89874
# No solution found for Machine 104
#
# Processing Machine 105
# Button A: X+31, Y+17
# Button B: X+24, Y+40
# Prize: X=10000000002311, Y=10000000008105
#
# Solving for equations:
# 31A + 24B = 10000000002311
# 17A + 40B = 10000000008105
# Found solution: A=192307692185, B=168269231024
# Solution found for Machine 105:
# Button A presses: 192307692185
# Button B presses: 168269231024
# Tokens needed: 745192307579
#
# Processing Machine 106
# Button A: X+58, Y+27
# Button B: X+19, Y+60
# Prize: X=10000000006022, Y=10000000006398
#
# Solving for equations:
# 58A + 19B = 10000000006022
# 27A + 60B = 10000000006398
# Found solution: A=138186720674, B=104482642470
# Solution found for Machine 106:
# Button A presses: 138186720674
# Button B presses: 104482642470
# Tokens needed: 519042804492
#
# Processing Machine 107
# Button A: X+13, Y+67
# Button B: X+84, Y+29
# Prize: X=10000000002843, Y=10000000002323
#
# Solving for equations:
# 13A + 84B = 10000000002843
# 67A + 29B = 10000000002323
# Found solution: A=104741953935, B=102837554782
# Solution found for Machine 107:
# Button A presses: 104741953935
# Button B presses: 102837554782
# Tokens needed: 417063416587
#
# Processing Machine 108
# Button A: X+56, Y+12
# Button B: X+23, Y+81
# Prize: X=10000000002380, Y=10000000011120
#
# Solving for equations:
# 56A + 23B = 10000000002380
# 12A + 81B = 10000000011120
# Found solution: A=136150234727, B=103286385116
# Solution found for Machine 108:
# Button A presses: 136150234727
# Button B presses: 103286385116
# Tokens needed: 511737089297
#
# Processing Machine 109
# Button A: X+15, Y+65
# Button B: X+56, Y+24
# Prize: X=10000000005230, Y=10000000005170
#
# Solving for equations:
# 15A + 56B = 10000000005230
# 65A + 24B = 10000000005170
# No valid solution: A=97560975659.7561, B=152439024470.2439
# No solution found for Machine 109
#
# Processing Machine 110
# Button A: X+19, Y+47
# Button B: X+72, Y+34
# Prize: X=10000000017967, Y=10000000011841
#
# Solving for equations:
# 19A + 72B = 10000000017967
# 47A + 34B = 10000000011841
# Found solution: A=138787436173, B=102264426815
# Solution found for Machine 110:
# Button A presses: 138787436173
# Button B presses: 102264426815
# Tokens needed: 518626735334
#
# Processing Machine 111
# Button A: X+16, Y+41
# Button B: X+78, Y+60
# Prize: X=10000000005144, Y=10000000004789
#
# Solving for equations:
# 16A + 78B = 10000000005144
# 41A + 60B = 10000000004789
# No valid solution: A=80428954452.5925, B=111706881203.87846
# No solution found for Machine 111
#
# Processing Machine 112
# Button A: X+52, Y+15
# Button B: X+16, Y+65
# Prize: X=10000000019732, Y=10000000007355
#
# Solving for equations:
# 52A + 16B = 10000000019732
# 15A + 65B = 10000000007355
# Found solution: A=156050955785, B=117834394932
# Solution found for Machine 112:
# Button A presses: 156050955785
# Button B presses: 117834394932
# Tokens needed: 585987262287
#
# Processing Machine 113
# Button A: X+21, Y+81
# Button B: X+71, Y+16
# Prize: X=10000000017221, Y=10000000009366
#
# Solving for equations:
# 21A + 71B = 10000000017221
# 81A + 16B = 10000000009366
# Found solution: A=101569713830, B=110803324321
# Solution found for Machine 113:
# Button A presses: 101569713830
# Button B presses: 110803324321
# Tokens needed: 415512465811
#
# Processing Machine 114
# Button A: X+61, Y+33
# Button B: X+49, Y+87
# Prize: X=10000000008507, Y=10000000009381
#
# Solving for equations:
# 61A + 49B = 10000000008507
# 33A + 87B = 10000000009381
# No valid solution: A=102981029886.2981, B=75880758886.58807
# No solution found for Machine 114
#
# Processing Machine 115
# Button A: X+67, Y+21
# Button B: X+15, Y+52
# Prize: X=10000000016737, Y=10000000007411
#
# Solving for equations:
# 67A + 15B = 10000000016737
# 21A + 52B = 10000000007411
# Found solution: A=116756074711, B=145156200740
# Solution found for Machine 115:
# Button A presses: 116756074711
# Button B presses: 145156200740
# Tokens needed: 495424424873
#
# Processing Machine 116
# Button A: X+33, Y+49
# Button B: X+34, Y+11
# Prize: X=10000000006660, Y=10000000004300
#
# Solving for equations:
# 33A + 34B = 10000000006660
# 49A + 11B = 10000000004300
# Found solution: A=176515732980, B=122793553480
# Solution found for Machine 116:
# Button A presses: 176515732980
# Button B presses: 122793553480
# Tokens needed: 652340752420
#
# Processing Machine 117
# Button A: X+19, Y+81
# Button B: X+96, Y+33
# Prize: X=10000000010734, Y=10000000010392
#
# Solving for equations:
# 19A + 96B = 10000000010734
# 81A + 33B = 10000000010392
# No valid solution: A=88124213266.66806, B=86725416236.11778
# No solution found for Machine 117
#
# Processing Machine 118
# Button A: X+60, Y+13
# Button B: X+63, Y+65
# Prize: X=10000000007395, Y=10000000003913
#
# Solving for equations:
# 60A + 63B = 10000000007395
# 13A + 65B = 10000000003913
# No valid solution: A=6491398972.462188, B=152547874111.86142
# No solution found for Machine 118
#
# Processing Machine 119
# Button A: X+15, Y+21
# Button B: X+96, Y+35
# Prize: X=10000000006417, Y=10000000003815
#
# Solving for equations:
# 15A + 96B = 10000000006417
# 21A + 35B = 10000000003815
# No valid solution: A=409121395131.888, B=40241448744.152916
# No solution found for Machine 119
#
# Processing Machine 120
# Button A: X+20, Y+39
# Button B: X+57, Y+27
# Prize: X=10000000000611, Y=10000000004760
#
# Solving for equations:
# 20A + 57B = 10000000000611
# 39A + 27B = 10000000004760
# Found solution: A=178253119581, B=112893642263
# Solution found for Machine 120:
# Button A presses: 178253119581
# Button B presses: 112893642263
# Tokens needed: 647653001006
#
# Processing Machine 121
# Button A: X+68, Y+97
# Button B: X+87, Y+37
# Prize: X=10000000011894, Y=10000000009824
#
# Solving for equations:
# 68A + 87B = 10000000011894
# 97A + 37B = 10000000009824
# No valid solution: A=84416680806.11345, B=48961674908.9458
# No solution found for Machine 121
#
# Processing Machine 122
# Button A: X+13, Y+81
# Button B: X+59, Y+12
# Prize: X=10000000018946, Y=10000000003392
#
# Solving for equations:
# 13A + 59B = 10000000018946
# 81A + 12B = 10000000003392
# Found solution: A=101665585112, B=147090634110
# Solution found for Machine 122:
# Button A presses: 101665585112
# Button B presses: 147090634110
# Tokens needed: 452087389446
#
# Processing Machine 123
# Button A: X+30, Y+83
# Button B: X+57, Y+11
# Prize: X=10000000003482, Y=10000000019301
#
# Solving for equations:
# 30A + 57B = 10000000003482
# 83A + 11B = 10000000019301
# Found solution: A=104521699855, B=120427175576
# Solution found for Machine 123:
# Button A presses: 104521699855
# Button B presses: 120427175576
# Tokens needed: 433992275141
#
# Processing Machine 124
# Button A: X+94, Y+11
# Button B: X+35, Y+92
# Prize: X=10000000011544, Y=10000000007680
#
# Solving for equations:
# 94A + 35B = 10000000011544
# 11A + 92B = 10000000007680
# No valid solution: A=68982209947.14365, B=100447779328.92848
# No solution found for Machine 124
#
# Processing Machine 125
# Button A: X+45, Y+19
# Button B: X+30, Y+45
# Prize: X=10000000011315, Y=10000000017659
#
# Solving for equations:
# 45A + 30B = 10000000011315
# 19A + 45B = 10000000017659
# Found solution: A=103092783491, B=178694158474
# Solution found for Machine 125:
# Button A presses: 103092783491
# Button B presses: 178694158474
# Tokens needed: 487972508947
#
# Processing Machine 126
# Button A: X+25, Y+42
# Button B: X+79, Y+21
# Prize: X=10000000007695, Y=10000000003990
#
# Solving for equations:
# 25A + 79B = 10000000007695
# 42A + 21B = 10000000003990
# No valid solution: A=207662012228.29037, B=60866451923.895454
# No solution found for Machine 126
#
# Processing Machine 127
# Button A: X+95, Y+91
# Button B: X+55, Y+13
# Prize: X=10000000010575, Y=10000000009217
#
# Solving for equations:
# 95A + 55B = 10000000010575
# 91A + 13B = 10000000009217
# No valid solution: A=111405835641.76657, B=-10610079552.596817
# No solution found for Machine 127
#
# Processing Machine 128
# Button A: X+27, Y+46
# Button B: X+81, Y+26
# Prize: X=10000000005508, Y=10000000002776
#
# Solving for equations:
# 27A + 81B = 10000000005508
# 46A + 26B = 10000000002776
# No valid solution: A=181878306905.3069, B=62830687889.68783
# No solution found for Machine 128
#
# Processing Machine 129
# Button A: X+20, Y+53
# Button B: X+29, Y+17
# Prize: X=10000000010985, Y=10000000016700
#
# Solving for equations:
# 20A + 29B = 10000000010985
# 53A + 17B = 10000000016700
# Found solution: A=100250626815, B=275689223265
# Solution found for Machine 129:
# Button A presses: 100250626815
# Button B presses: 275689223265
# Tokens needed: 576441103710
#
# Processing Machine 130
# Button A: X+55, Y+74
# Button B: X+58, Y+20
# Prize: X=10000000008888, Y=10000000008128
#
# Solving for equations:
# 55A + 58B = 10000000008888
# 74A + 20B = 10000000008128
# No valid solution: A=119047619139.61905, B=59523809589.809525
# No solution found for Machine 130
#
# Processing Machine 131
# Button A: X+40, Y+27
# Button B: X+19, Y+43
# Prize: X=10000000005535, Y=10000000001095
#
# Solving for equations:
# 40A + 19B = 10000000005535
# 27A + 43B = 10000000001095
# Found solution: A=198840099600, B=107705053765
# Solution found for Machine 131:
# Button A presses: 198840099600
# Button B presses: 107705053765
# Tokens needed: 704225352565
#
# Processing Machine 132
# Button A: X+19, Y+72
# Button B: X+54, Y+22
# Prize: X=10000000003261, Y=10000000002678
#
# Solving for equations:
# 19A + 54B = 10000000003261
# 72A + 22B = 10000000002678
# No valid solution: A=92219020193.91066, B=152737752214.38327
# No solution found for Machine 132
#
# Processing Machine 133
# Button A: X+79, Y+39
# Button B: X+38, Y+75
# Prize: X=10000000007120, Y=10000000006102
#
# Solving for equations:
# 79A + 38B = 10000000007120
# 39A + 75B = 10000000006102
# No valid solution: A=83277065114.14, B=90029259555.34053
# No solution found for Machine 133
#
# Processing Machine 134
# Button A: X+26, Y+91
# Button B: X+99, Y+25
# Prize: X=10000000001223, Y=10000000002673
#
# Solving for equations:
# 26A + 99B = 10000000001223
# 91A + 25B = 10000000002673
# No valid solution: A=88527335833.71838, B=77760497672.18507
# No solution found for Machine 134
#
# Processing Machine 135
# Button A: X+15, Y+28
# Button B: X+58, Y+23
# Prize: X=10000000001519, Y=10000000005600
#
# Solving for equations:
# 15A + 58B = 10000000001519
# 28A + 23B = 10000000005600
# Found solution: A=273651290297, B=101641907708
# Solution found for Machine 135:
# Button A presses: 273651290297
# Button B presses: 101641907708
# Tokens needed: 922595778599
#
# Processing Machine 136
# Button A: X+18, Y+53
# Button B: X+71, Y+27
# Prize: X=10000000011055, Y=10000000003487
#
# Solving for equations:
# 18A + 71B = 10000000011055
# 53A + 27B = 10000000003487
# Found solution: A=134269148596, B=106805004737
# Solution found for Machine 136:
# Button A presses: 134269148596
# Button B presses: 106805004737
# Tokens needed: 509612450525
#
# Processing Machine 137
# Button A: X+14, Y+50
# Button B: X+52, Y+18
# Prize: X=10000000003908, Y=10000000008576
#
# Solving for equations:
# 14A + 52B = 10000000003908
# 50A + 18B = 10000000008576
# Found solution: A=144804088746, B=153321976182
# Solution found for Machine 137:
# Button A presses: 144804088746
# Button B presses: 153321976182
# Tokens needed: 587734242420
#
# Processing Machine 138
# Button A: X+38, Y+17
# Button B: X+23, Y+50
# Prize: X=10000000007788, Y=10000000008394
#
# Solving for equations:
# 38A + 23B = 10000000007788
# 17A + 50B = 10000000008394
# Found solution: A=178926441482, B=139165010064
# Solution found for Machine 138:
# Button A presses: 178926441482
# Button B presses: 139165010064
# Tokens needed: 675944334510
#
# Processing Machine 139
# Button A: X+72, Y+20
# Button B: X+19, Y+68
# Prize: X=10000000010586, Y=10000000004272
#
# Solving for equations:
# 72A + 19B = 10000000010586
# 20A + 68B = 10000000004272
# Found solution: A=108503100230, B=115146147054
# Solution found for Machine 139:
# Button A presses: 108503100230
# Button B presses: 115146147054
# Tokens needed: 440655447744
#
# Processing Machine 140
# Button A: X+28, Y+66
# Button B: X+62, Y+12
# Prize: X=10000000019418, Y=10000000007934
#
# Solving for equations:
# 28A + 62B = 10000000019418
# 66A + 12B = 10000000007934
# Found solution: A=133120340857, B=101171459281
# Solution found for Machine 140:
# Button A presses: 133120340857
# Button B presses: 101171459281
# Tokens needed: 500532481852
#
# Processing Machine 141
# Button A: X+11, Y+20
# Button B: X+49, Y+24
# Prize: X=10000000002957, Y=10000000002252
#
# Solving for equations:
# 11A + 49B = 10000000002957
# 20A + 24B = 10000000002252
# No valid solution: A=349162011228.1844, B=125698324070.34637
# No solution found for Machine 141
#
# Processing Machine 142
# Button A: X+60, Y+11
# Button B: X+27, Y+84
# Prize: X=10000000003146, Y=10000000001936
#
# Solving for equations:
# 60A + 27B = 10000000003146
# 11A + 84B = 10000000001936
# Found solution: A=120177103144, B=103310141278
# Solution found for Machine 142:
# Button A presses: 120177103144
# Button B presses: 103310141278
# Tokens needed: 463841450710
#
# Processing Machine 143
# Button A: X+18, Y+11
# Button B: X+11, Y+41
# Prize: X=10000000009360, Y=10000000018112
#
# Solving for equations:
# 18A + 11B = 10000000009360
# 11A + 41B = 10000000018112
# Found solution: A=486223663184, B=113452188368
# Solution found for Machine 143:
# Button A presses: 486223663184
# Button B presses: 113452188368
# Tokens needed: 1572123177920
#
# Processing Machine 144
# Button A: X+70, Y+31
# Button B: X+15, Y+62
# Prize: X=10000000013135, Y=10000000007958
#
# Solving for equations:
# 70A + 15B = 10000000013135
# 31A + 62B = 10000000007958
# Found solution: A=121290322760, B=100645161329
# Solution found for Machine 144:
# Button A presses: 121290322760
# Button B presses: 100645161329
# Tokens needed: 464516129609
#
# Processing Machine 145
# Button A: X+74, Y+35
# Button B: X+11, Y+41
# Prize: X=10000000019668, Y=10000000014478
#
# Solving for equations:
# 74A + 11B = 10000000019668
# 35A + 41B = 10000000014478
# Found solution: A=113250283370, B=147225368208
# Solution found for Machine 145:
# Button A presses: 113250283370
# Button B presses: 147225368208
# Tokens needed: 486976218318
#
# Processing Machine 146
# Button A: X+53, Y+89
# Button B: X+54, Y+23
# Prize: X=10000000009521, Y=10000000010100
#
# Solving for equations:
# 53A + 54B = 10000000009521
# 89A + 23B = 10000000010100
# No valid solution: A=86423194961.3652, B=100362419936.45638
# No solution found for Machine 146
#
# Processing Machine 147
# Button A: X+13, Y+61
# Button B: X+68, Y+28
# Prize: X=10000000011028, Y=10000000012380
#
# Solving for equations:
# 13A + 68B = 10000000011028
# 61A + 28B = 10000000012380
# Found solution: A=105708245384, B=126849894427
# Solution found for Machine 147:
# Button A presses: 105708245384
# Button B presses: 126849894427
# Tokens needed: 443974630579
#
# Processing Machine 148
# Button A: X+42, Y+29
# Button B: X+20, Y+74
# Prize: X=10000000001906, Y=10000000001617
#
# Solving for equations:
# 42A + 20B = 10000000001906
# 29A + 74B = 10000000001617
# No valid solution: A=213607594979.70886, B=51424050637.91139
# No solution found for Machine 148
#
# Processing Machine 149
# Button A: X+44, Y+13
# Button B: X+23, Y+60
# Prize: X=10000000013690, Y=10000000009554
#
# Solving for equations:
# 44A + 23B = 10000000013690
# 13A + 60B = 10000000009554
# Found solution: A=158052114738, B=132422041966
# Solution found for Machine 149:
# Button A presses: 158052114738
# Button B presses: 132422041966
# Tokens needed: 606578386180
#
# Processing Machine 150
# Button A: X+54, Y+16
# Button B: X+11, Y+23
# Prize: X=10000000003792, Y=10000000004614
#
# Solving for equations:
# 54A + 11B = 10000000003792
# 16A + 23B = 10000000004614
# Found solution: A=112570356507, B=356472795674
# Solution found for Machine 150:
# Button A presses: 112570356507
# Button B presses: 356472795674
# Tokens needed: 694183865195
#
# Processing Machine 151
# Button A: X+28, Y+11
# Button B: X+34, Y+63
# Prize: X=10000000013092, Y=10000000015599
#
# Solving for equations:
# 28A + 34B = 10000000013092
# 11A + 63B = 10000000015599
# Found solution: A=208633093737, B=122302158484
# Solution found for Machine 151:
# Button A presses: 208633093737
# Button B presses: 122302158484
# Tokens needed: 748201439695
#
# Processing Machine 152
# Button A: X+61, Y+14
# Button B: X+33, Y+73
# Prize: X=10000000018520, Y=10000000000772
#
# Solving for equations:
# 61A + 33B = 10000000018520
# ...
# Found solution: A=117647058984, B=117647058869
# Solution found for Machine 271:
# Button A presses: 117647058984
# Button B presses: 117647058869
# Tokens needed: 470588235821
#
# Processing Machine 272
# Button A: X+14, Y+58
# Button B: X+68, Y+27
# Prize: X=10000000007972, Y=10000000015348
#
# Solving for equations:
# 14A + 68B = 10000000007972
# 58A + 27B = 10000000015348
# Found solution: A=114974761870, B=123387549144
# Solution found for Machine 272:
# Button A presses: 114974761870
# Button B presses: 123387549144
# Tokens needed: 468311834754
#
# Processing Machine 273
# Button A: X+46, Y+17
# Button B: X+29, Y+96
# Prize: X=10000000003598, Y=10000000008664
#
# Solving for equations:
# 46A + 29B = 10000000003598
# 17A + 96B = 10000000008664
# No valid solution: A=170787662527.18634, B=73923018184.39409
# No solution found for Machine 273
#
# Processing Machine 274
# Button A: X+93, Y+32
# Button B: X+28, Y+76
# Prize: X=10000000011382, Y=10000000009292
#
# Solving for equations:
# 93A + 28B = 10000000011382
# 32A + 76B = 10000000009292
# No valid solution: A=77770576896.4446, B=98833441429.02333
# No solution found for Machine 274
#
# Processing Machine 275
# Button A: X+65, Y+24
# Button B: X+11, Y+35
# Prize: X=10000000002252, Y=10000000010494
#
# Solving for equations:
# 65A + 11B = 10000000002252
# 24A + 35B = 10000000010494
# Found solution: A=119343610126, B=203878667642
# Solution found for Machine 275:
# Button A presses: 119343610126
# Button B presses: 203878667642
# Tokens needed: 561909498020
#
# Processing Machine 276
# Button A: X+28, Y+61
# Button B: X+46, Y+16
# Prize: X=10000000014138, Y=10000000007874
#
# Solving for equations:
# 28A + 46B = 10000000014138
# 61A + 16B = 10000000007874
# Found solution: A=127226463162, B=139949109687
# Solution found for Machine 276:
# Button A presses: 127226463162
# Button B presses: 139949109687
# Tokens needed: 521628499173
#
# Processing Machine 277
# Button A: X+49, Y+28
# Button B: X+29, Y+66
# Prize: X=10000000002640, Y=10000000004672
#
# Solving for equations:
# 49A + 29B = 10000000002640
# 28A + 66B = 10000000004672
# No valid solution: A=152766308851.673, B=86705202376.13873
# No solution found for Machine 277
#
# Processing Machine 278
# Button A: X+14, Y+99
# Button B: X+98, Y+68
# Prize: X=10000000002730, Y=10000000005555
#
# Solving for equations:
# 14A + 98B = 10000000002730
# 99A + 68B = 10000000005555
# No valid solution: A=34285714326.714287, B=97142857164.85715
# No solution found for Machine 278
#
# Processing Machine 279
# Button A: X+54, Y+54
# Button B: X+89, Y+22
# Prize: X=10000000005618, Y=10000000003340
#
# Solving for equations:
# 54A + 89B = 10000000005618
# 54A + 22B = 10000000003340
# No valid solution: A=185185185233.18518, B=34.0
# No solution found for Machine 279
#
# Processing Machine 280
# Button A: X+18, Y+46
# Button B: X+76, Y+48
# Prize: X=10000000005930, Y=10000000002346
#
# Solving for equations:
# 18A + 76B = 10000000005930
# 46A + 48B = 10000000002346
# Found solution: A=106382978683, B=106382978811
# Solution found for Machine 280:
# Button A presses: 106382978683
# Button B presses: 106382978811
# Tokens needed: 425531914860
#
# Processing Machine 281
# Button A: X+78, Y+75
# Button B: X+87, Y+21
# Prize: X=10000000003906, Y=10000000002628
#
# Solving for equations:
# 78A + 87B = 10000000003906
# 75A + 21B = 10000000002628
# No valid solution: A=135052179281.07428, B=-6138735402.503376
# No solution found for Machine 281
#
# Processing Machine 282
# Button A: X+14, Y+22
# Button B: X+41, Y+19
# Prize: X=10000000003378, Y=10000000012850
#
# Solving for equations:
# 14A + 41B = 10000000003378
# 22A + 19B = 10000000012850
# Found solution: A=345911950413, B=125786163356
# Solution found for Machine 282:
# Button A presses: 345911950413
# Button B presses: 125786163356
# Tokens needed: 1163522014595
#
# Processing Machine 283
# Button A: X+69, Y+18
# Button B: X+18, Y+73
# Prize: X=10000000006411, Y=10000000002697
#
# Solving for equations:
# 69A + 18B = 10000000006411
# 18A + 73B = 10000000002697
# No valid solution: A=116698493617.53809, B=108211330377.82623
# No solution found for Machine 283
#
# Processing Machine 284
# Button A: X+33, Y+78
# Button B: X+70, Y+37
# Prize: X=10000000003122, Y=10000000006737
#
# Solving for equations:
# 33A + 70B = 10000000003122
# 78A + 37B = 10000000006737
# No valid solution: A=77848549270.1288, B=106157112531.53928
# No solution found for Machine 284
#
# Processing Machine 285
# Button A: X+14, Y+74
# Button B: X+86, Y+20
# Prize: X=10000000006300, Y=10000000002880
#
# Solving for equations:
# 14A + 86B = 10000000006300
# 74A + 20B = 10000000002880
# No valid solution: A=108481262347.41617, B=98619329458.56017
# No solution found for Machine 285
#
# Processing Machine 286
# Button A: X+11, Y+28
# Button B: X+48, Y+11
# Prize: X=10000000006804, Y=10000000016815
#
# Solving for equations:
# 11A + 48B = 10000000006804
# 28A + 11B = 10000000016815
# Found solution: A=302534751212, B=139002452989
# Solution found for Machine 286:
# Button A presses: 302534751212
# Button B presses: 139002452989
# Tokens needed: 1046606706625
#
# Processing Machine 287
# Button A: X+62, Y+17
# Button B: X+31, Y+65
# Prize: X=10000000006448, Y=10000000004141
#
# Solving for equations:
# 62A + 31B = 10000000006448
# 17A + 65B = 10000000004141
# No valid solution: A=97059663228.87497, B=128461318911.54039
# No solution found for Machine 287
#
# Processing Machine 288
# Button A: X+70, Y+11
# Button B: X+72, Y+59
# Prize: X=10000000004918, Y=10000000001202
#
# Solving for equations:
# 70A + 72B = 10000000004918
# 11A + 59B = 10000000001202
# No valid solution: A=-38945476272.13361, B=176752546443.99103
# No solution found for Machine 288
#
# Processing Machine 289
# Button A: X+97, Y+67
# Button B: X+13, Y+33
# Prize: X=10000000008935, Y=10000000007805
#
# Solving for equations:
# 97A + 13B = 10000000008935
# 67A + 33B = 10000000007805
# No valid solution: A=85836909954.24463, B=128755364874.86696
# No solution found for Machine 289
#
# Processing Machine 290
# Button A: X+34, Y+78
# Button B: X+76, Y+49
# Prize: X=10000000008860, Y=10000000010423
#
# Solving for equations:
# 34A + 76B = 10000000008860
# 78A + 49B = 10000000010423
# No valid solution: A=63350539736.74519, B=103237916550.1403
# No solution found for Machine 290
#
# Processing Machine 291
# Button A: X+27, Y+69
# Button B: X+37, Y+21
# Prize: X=10000000001124, Y=10000000000960
#
# Solving for equations:
# 27A + 37B = 10000000001124
# 69A + 21B = 10000000000960
# No valid solution: A=80563947639.43404, B=211480362563.76434
# No solution found for Machine 291
#
# Processing Machine 292
# Button A: X+25, Y+11
# Button B: X+15, Y+53
# Prize: X=10000000011185, Y=10000000017987
#
# Solving for equations:
# 25A + 15B = 10000000011185
# 11A + 53B = 10000000017987
# Found solution: A=327586207175, B=120689655454
# Solution found for Machine 292:
# Button A presses: 327586207175
# Button B presses: 120689655454
# Tokens needed: 1103448276979
#
# Processing Machine 293
# Button A: X+12, Y+57
# Button B: X+67, Y+20
# Prize: X=10000000010831, Y=10000000011898
#
# Solving for equations:
# 12A + 67B = 10000000010831
# 57A + 20B = 10000000011898
# Found solution: A=131321598374, B=125733445229
# Solution found for Machine 293:
# Button A presses: 131321598374
# Button B presses: 125733445229
# Tokens needed: 519698240351
#
# Processing Machine 294
# Button A: X+21, Y+52
# Button B: X+68, Y+37
# Prize: X=10000000000488, Y=10000000019181
#
# Solving for equations:
# 21A + 68B = 10000000000488
# 52A + 37B = 10000000019181
# Found solution: A=112359551028, B=112359550425
# Solution found for Machine 294:
# Button A presses: 112359551028
# Button B presses: 112359550425
# Tokens needed: 449438203509
#
# Processing Machine 295
# Button A: X+27, Y+12
# Button B: X+30, Y+67
# Prize: X=10000000004040, Y=10000000008930
#
# Solving for equations:
# 27A + 30B = 10000000004040
# 12A + 67B = 10000000008930
# Found solution: A=255348516220, B=103519668870
# Solution found for Machine 295:
# Button A presses: 255348516220
# Button B presses: 103519668870
# Tokens needed: 869565217530
#
# Processing Machine 296
# Button A: X+84, Y+30
# Button B: X+58, Y+99
# Prize: X=10000000004462, Y=10000000006369
#
# Solving for equations:
# 84A + 58B = 10000000004462
# 30A + 99B = 10000000006369
# No valid solution: A=62347931884.47932, B=82116788382.16788
# No solution found for Machine 296
#
# Processing Machine 297
# Button A: X+32, Y+59
# Button B: X+37, Y+20
# Prize: X=10000000012149, Y=10000000003281
#
# Solving for equations:
# 32A + 37B = 10000000012149
# 59A + 20B = 10000000003281
# Found solution: A=110174983719, B=174983798193
# Solution found for Machine 297:
# Button A presses: 110174983719
# Button B presses: 174983798193
# Tokens needed: 505508749350
#
# Processing Machine 298
# Button A: X+44, Y+12
# Button B: X+86, Y+94
# Prize: X=10000000007916, Y=10000000008508
#
# Solving for equations:
# 44A + 86B = 10000000007916
# 12A + 94B = 10000000008508
# No valid solution: A=25773195880.28866, B=103092783595.15463
# No solution found for Machine 298
#
# Processing Machine 299
# Button A: X+11, Y+42
# Button B: X+64, Y+29
# Prize: X=10000000001438, Y=10000000007055
#
# Solving for equations:
# 11A + 64B = 10000000001438
# 42A + 29B = 10000000007055
# Found solution: A=147741663322, B=130856901639
# Solution found for Machine 299:
# Button A presses: 147741663322
# Button B presses: 130856901639
# Tokens needed: 574081891605
#
# Processing Machine 300
# Button A: X+13, Y+58
# Button B: X+71, Y+30
# Prize: X=10000000001136, Y=10000000007488
#
# Solving for equations:
# 13A + 71B = 10000000001136
# 58A + 30B = 10000000007488
# Found solution: A=109978540906, B=120708154498
# Solution found for Machine 300:
# Button A presses: 109978540906
# Button B presses: 120708154498
# Tokens needed: 450643777216
#
# Processing Machine 301
# Button A: X+29, Y+32
# Button B: X+15, Y+73
# Prize: X=10000000000466, Y=10000000000740
#
# Solving for equations:
# 29A + 15B = 10000000000466
# 32A + 73B = 10000000000740
# No valid solution: A=354306658535.68604, B=-18326206471.25962
# No solution found for Machine 301
#
# Processing Machine 302
# Button A: X+18, Y+40
# Button B: X+60, Y+14
# Prize: X=10000000003758, Y=10000000016800
#
# Solving for equations:
# 18A + 60B = 10000000003758
# 40A + 14B = 10000000016800
# Found solution: A=214152700631, B=102420856540
# Solution found for Machine 302:
# Button A presses: 214152700631
# Button B presses: 102420856540
# Tokens needed: 744878958433
#
# Processing Machine 303
# Button A: X+29, Y+48
# Button B: X+46, Y+11
# Prize: X=10000000000823, Y=10000000004172
#
# Solving for equations:
# 29A + 46B = 10000000000823
# 48A + 11B = 10000000004172
# Found solution: A=185283218731, B=100582318644
# Solution found for Machine 303:
# Button A presses: 185283218731
# Button B presses: 100582318644
# Tokens needed: 656431974837
#
# Processing Machine 304
# Button A: X+12, Y+36
# Button B: X+84, Y+21
# Prize: X=10000000002916, Y=10000000001818
#
# Solving for equations:
# 12A + 84B = 10000000002916
# 36A + 21B = 10000000001818
# No valid solution: A=227272727305.72726, B=86580086610.08658
# No solution found for Machine 304
#
# Processing Machine 305
# Button A: X+57, Y+98
# Button B: X+99, Y+38
# Prize: X=10000000011955, Y=10000000007862
#
# Solving for equations:
# 57A + 99B = 10000000011955
# 98A + 38B = 10000000007862
# No valid solution: A=80944798344.4862, B=54405520265.85138
# No solution found for Machine 305
#
# Processing Machine 306
# Button A: X+11, Y+59
# Button B: X+54, Y+19
# Prize: X=10000000005556, Y=10000000008121
#
# Solving for equations:
# 11A + 54B = 10000000005556
# 59A + 19B = 10000000008121
# Found solution: A=117568021610, B=161236143849
# Solution found for Machine 306:
# Button A presses: 117568021610
# Button B presses: 161236143849
# Tokens needed: 513940208679
#
# Processing Machine 307
# Button A: X+42, Y+16
# Button B: X+25, Y+46
# Prize: X=10000000006595, Y=10000000007886
#
# Solving for equations:
# 42A + 25B = 10000000006595
# 16A + 46B = 10000000007886
# Found solution: A=137075718085, B=169712793881
# Solution found for Machine 307:
# Button A presses: 137075718085
# Button B presses: 169712793881
# Tokens needed: 580939948136
#
# Processing Machine 308
# Button A: X+18, Y+38
# Button B: X+51, Y+33
# Prize: X=10000000010826, Y=10000000015950
#
# Solving for equations:
# 18A + 51B = 10000000010826
# 38A + 33B = 10000000015950
# Found solution: A=133928571768, B=148809523902
# Solution found for Machine 308:
# Button A presses: 133928571768
# Button B presses: 148809523902
# Tokens needed: 550595239206
#
# Processing Machine 309
# Button A: X+30, Y+52
# Button B: X+24, Y+11
# Prize: X=10000000018374, Y=10000000018262
#
# Solving for equations:
# 30A + 24B = 10000000018374
# 52A + 11B = 10000000018262
# Found solution: A=141612200693, B=239651416566
# Solution found for Machine 309:
# Button A presses: 141612200693
# Button B presses: 239651416566
# Tokens needed: 664488018645
#
# Processing Machine 310
# Button A: X+43, Y+17
# Button B: X+20, Y+51
# Prize: X=10000000006909, Y=10000000005174
#
# Solving for equations:
# 43A + 20B = 10000000006909
# 17A + 51B = 10000000005174
# Found solution: A=167296276443, B=140313005993
# Solution found for Machine 310:
# Button A presses: 167296276443
# Button B presses: 140313005993
# Tokens needed: 642201835322
#
# Processing Machine 311
# Button A: X+12, Y+49
# Button B: X+73, Y+35
# Prize: X=10000000019520, Y=10000000007473
#
# Solving for equations:
# 12A + 73B = 10000000019520
# 49A + 35B = 10000000007473
# Found solution: A=120367437397, B=117199873572
# Solution found for Machine 311:
# Button A presses: 120367437397
# Button B presses: 117199873572
# Tokens needed: 478302185763
#
# Processing Machine 312
# Button A: X+26, Y+54
# Button B: X+81, Y+18
# Prize: X=10000000002771, Y=10000000001098
#
# Solving for equations:
# 26A + 81B = 10000000002771
# 54A + 18B = 10000000001098
# No valid solution: A=161290322590.64517, B=71684587844.62007
# No solution found for Machine 312
#
# Processing Machine 313
# Button A: X+38, Y+16
# Button B: X+35, Y+56
# Prize: X=10000000009775, Y=10000000016248
#
# Solving for equations:
# 38A + 35B = 10000000009775
# 16A + 56B = 10000000016248
# Found solution: A=133928571415, B=140306122743
# Solution found for Machine 313:
# Button A presses: 133928571415
# Button B presses: 140306122743
# Tokens needed: 542091836988
#
# Processing Machine 314
# Button A: X+74, Y+12
# Button B: X+13, Y+83
# Prize: X=10000000017184, Y=10000000008706
#
# Solving for equations:
# 74A + 13B = 10000000017184
# 12A + 83B = 10000000008706
# Found solution: A=116939525779, B=103575008426
# Solution found for Machine 314:
# Button A presses: 116939525779
# Button B presses: 103575008426
# Tokens needed: 454393585763
#
# Processing Machine 315
# Button A: X+47, Y+15
# Button B: X+59, Y+68
# Prize: X=10000000006455, Y=10000000005207
#
# Solving for equations:
# 47A + 59B = 10000000006455
# 15A + 68B = 10000000005207
# No valid solution: A=38944180065.65426, B=138468195650.32626
# No solution found for Machine 315
#
# Processing Machine 316
# Button A: X+51, Y+75
# Button B: X+73, Y+35
# Prize: X=10000000003535, Y=10000000004475
#
# Solving for equations:
# 51A + 73B = 10000000003535
# 75A + 35B = 10000000004475
# No valid solution: A=102981029865.2981, B=65040650416.50407
# No solution found for Machine 316
#
# Processing Machine 317
# Button A: X+11, Y+49
# Button B: X+43, Y+19
# Prize: X=10000000015272, Y=10000000002282
#
# Solving for equations:
# 11A + 43B = 10000000015272
# 49A + 19B = 10000000002282
# Found solution: A=126448893471, B=200210748537
# Solution found for Machine 317:
# Button A presses: 126448893471
# Button B presses: 200210748537
# Tokens needed: 579557428950
#
# Processing Machine 318
# Button A: X+64, Y+12
# Button B: X+12, Y+73
# Prize: X=10000000002236, Y=10000000007049
#
# Solving for equations:
# 64A + 12B = 10000000002236
# 12A + 73B = 10000000007049
# Found solution: A=134717314505, B=114840989493
# Solution found for Machine 318:
# Button A presses: 134717314505
# Button B presses: 114840989493
# Tokens needed: 518992933008
#
# Processing Machine 319
# Button A: X+80, Y+36
# Button B: X+18, Y+61
# Prize: X=10000000019208, Y=10000000011960
#
# Solving for equations:
# 80A + 18B = 10000000019208
# 36A + 61B = 10000000011960
# Found solution: A=101606805519, B=103969754316
# Solution found for Machine 319:
# Button A presses: 101606805519
# Button B presses: 103969754316
# Tokens needed: 408790170873
#
# Processing Machine 320
# Button A: X+52, Y+21
# Button B: X+11, Y+35
# Prize: X=10000000004204, Y=10000000000354
#
# Solving for equations:
# 52A + 11B = 10000000004204
# 21A + 35B = 10000000000354
# Found solution: A=151038389014, B=195091252316
# Solution found for Machine 320:
# Button A presses: 151038389014
# Button B presses: 195091252316
# Tokens needed: 648206419358
#
# Final Results:
# Total possible prizes: 169
# Total tokens needed: 98080815200063
